# %%
import openpyxl as oxl
import xlwings as xw
from openpyxl.styles import Font
from openpyxl.writer.write_only import WriteOnlyCell
from openpyxl.styles.fills import PatternFill
from openpyxl.styles.borders import Border, Side
from openpyxl.styles.alignment import Alignment

# %%
'''
Program Constants
'''

WORKBOOK_PATH = 'test-book.xlsm'

RTE_SHEET = 'RTE Spreadsheet'
SM_SHEET = 'SM Spreadsheet'
MM_SHEET = 'MM Spreadsheet'

OUTPUT_TAB = 'RTE-SM Compare'

RTE_VALIDATION = 'Production MM'
SM_VALIDATION = 'SM Version'
MM_VALIDATION = 'Production MM'

OPERATION_START = 'Full Oper Num'

SAVE_ROOT_PATH = ''
HEADER_BUFFER = 3
NUM_OUTPUT_COLS = 30
COL_A = 0
COL_B = 1

RED = 'FFFF0000'
RTE_HEX = 'FFF0F0F0'
SM_HEX = 'FFFFFF99'
ORANGE_DIFF_HEX = 'FFFF9966'
BLUE_DIFF_HEX = 'FF00B0F0'

RTE_FILL = PatternFill(patternType='solid', fgColor=RTE_HEX)
SM_FILL = PatternFill(patternType='solid', fgColor=SM_HEX)
ORANGE_DIFF_FILL = PatternFill(patternType='solid', fgColor=ORANGE_DIFF_HEX)
BLUE_DIFF_FILL = PatternFill(patternType='solid', fgColor=BLUE_DIFF_HEX)

HEADER_FONT = Font(name='Calibri', bold=True, size=14)

ALL_BORDER = Border(left=Side(style='thin'),
                    right=Side(style='thin'),
                    top=Side(style='thin'),
                    bottom=Side(style='thin'))

CENTER_ALIGN = Alignment(horizontal='center')

BLUE = 'Blue'
ORANGE = 'Orange'

# %%
'''
High-level program logic
'''
def load_route(sheetname):
    '''
    @sheet: 
    '''
    sheet = oxl.load_workbook(WORKBOOK_PATH, read_only=True)[sheetname]
    
    '''
    @report_id:
    @start_reading:
    @start_index:
    '''
    report_id = ''
    start_reading = False
    start_index = -1
    
    '''
    @loop:
    @operation:
    @route:
    '''
    operation = Operation()
    route = Route()
    for index, row in enumerate(sheet.rows):
        
        #Get flow report header store in report_id
        if 'Flow Report' in stringify(row[COL_A]):
            report_id = stringify(row[COL_A])
            
        #If we encounter 'Full Oper Num', set the start index to two rows later
        if stringify(row[COL_B]) == OPERATION_START:
            start_index = index + 2
        
        #First row of operations, set flag to begin reading data
        if index == start_index:
            start_reading = True
            
        #'Read data mode'
        if start_reading:
            
            #If the current operation list isn't empty (accounting for first loop iteration)
            #and the current cell contains an operation number
            #store the operation in the route, clear out temp operation
            if has_value(row[COL_B]) and not operation.is_empty():
                if not operation.flagged_for_removal:
                    route.add_operation(operation)
                else:
                    print('Operation flagged for removal. Ignoring operation:', operation)
                operation = Operation()               
                
            #If the current row is not all empty cells, add it to the current operation
            operation.add_row(row)
                
    #Last operation will still be stored but not added
    if not operation.is_empty():
        route.add_operation(operation)  
        
    #Set route attributes
    route.set_route_id(get_route_id(report_id))
    route.set_product_id(get_product_id(report_id))
    route.set_route_type(sheetname)
    
    return route


# 'main' function area

#load routes
rte_route = load_route(RTE_SHEET)
sm_route = load_route(SM_SHEET)
mm_route = load_route(MM_SHEET)
print(rte_route)
print(sm_route)
print(mm_route)

#prep output
output_workbook = init_write_only_output()
output_worksheet = output_workbook[OUTPUT_TAB]

#compare routes
compare_routes(rte_route, sm_route, mm_route)

#save output
save_output()
print('Complete.')
# Out:
# Operation flagged for removal. Ignoring operation: 6885.6400
# Operation flagged for removal. Ignoring operation: 6885.6450
# Operation flagged for removal. Ignoring operation: 6885.6500
# Operation flagged for removal. Ignoring operation: 6885.6510
# Operation flagged for removal. Ignoring operation: 6885.7700
# Operation flagged for removal. Ignoring operation: 6885.7701
# Operation flagged for removal. Ignoring operation: 6885.7705
# Operation flagged for removal. Ignoring operation: 6885.7710
# Operation flagged for removal. Ignoring operation: 6885.7715
# Operation flagged for removal. Ignoring operation: 6885.7720
# Operation flagged for removal. Ignoring operation: 6885.7725
# Operation flagged for removal. Ignoring operation: 6885.7730
# Route ID: FF-MPW1409S9MIMDV.01, MPW14091MD.A9 | RTE Spreadsheet | No. of Operations: 710
# Route ID: FF-MPW1409S9MIMDV.01, MPW14091MD.A9 | SM Spreadsheet | No. of Operations: 710
# Route ID: FF-MPW1409S9MIMDV.01, MPW14091MD.A9 | MM Spreadsheet | No. of Operations: 706
# [+]Comparing RTE: 100.1000 SM: 100.1000
# 	[+]Operations equal.: 100.1000 SM: 100.1000
# [+]Comparing RTE: 2620.1000 SM: 2620.1000
# 	[+]Operations equal.: 2620.1000 SM: 2620.1000
# [+]Comparing RTE: 2620.2000 SM: 2620.2000
# 	[+]Operations equal.: 2620.2000 SM: 2620.2000
# [+]Comparing RTE: 2620.3000 SM: 2620.3000
# 	[+]Operations equal.: 2620.3000 SM: 2620.3000
# [+]Comparing RTE: 2620.4000 SM: 2620.4000
# 	[+]Operations equal.: 2620.4000 SM: 2620.4000
# [+]Comparing RTE: 2620.5000 SM: 2620.5000
# 	[+]Operations equal.: 2620.5000 SM: 2620.5000
# [+]Comparing RTE: 2620.6000 SM: 2620.6000
# 	[+]Operations equal.: 2620.6000 SM: 2620.6000
# [+]Comparing RTE: 2625.1001 SM: 2625.1001
# 	[+]Operations equal.: 2625.1001 SM: 2625.1001
# [+]Comparing RTE: 2625.2001 SM: 2625.2001
# 	[+]Operations equal.: 2625.2001 SM: 2625.2001
# [+]Comparing RTE: 2625.3001 SM: 2625.3001
# 	[+]Operations equal.: 2625.3001 SM: 2625.3001
# [+]Comparing RTE: 2625.4001 SM: 2625.4001
# 	[+]Operations equal.: 2625.4001 SM: 2625.4001
# [+]Comparing RTE: 2625.5001 SM: 2625.5001
# 	[+]Operations equal.: 2625.5001 SM: 2625.5001
# [+]Comparing RTE: 2630.1001 SM: 2630.1001
# 	[+]Operations equal.: 2630.1001 SM: 2630.1001
# [+]Comparing RTE: 2630.2001 SM: 2630.2001
# 	[+]Operations equal.: 2630.2001 SM: 2630.2001
# [+]Comparing RTE: 2630.3001 SM: 2630.3001
# 	[+]Operations equal.: 2630.3001 SM: 2630.3001
# [+]Comparing RTE: 2630.4001 SM: 2630.4001
# 	[+]Operations equal.: 2630.4001 SM: 2630.4001
# [+]Comparing RTE: 2630.5001 SM: 2630.5001
# 	[+]Operations equal.: 2630.5001 SM: 2630.5001
# [+]Comparing RTE: 2635.0550 SM: 2635.0550
# 	[+]Operations equal.: 2635.0550 SM: 2635.0550
# [+]Comparing RTE: 2635.0600 SM: 2635.0600
# 	[+]Operations equal.: 2635.0600 SM: 2635.0600
# [+]Comparing RTE: 2635.0700 SM: 2635.0700
# 	[+]Operations equal.: 2635.0700 SM: 2635.0700
# [+]Comparing RTE: 2635.0750 SM: 2635.0750
# 	[+]Operations equal.: 2635.0750 SM: 2635.0750
# [+]Comparing RTE: 2635.0800 SM: 2635.0800
# 	[+]Operations equal.: 2635.0800 SM: 2635.0800
# [+]Comparing RTE: 2635.0805 SM: 2635.0805
# 	[+]Operations equal.: 2635.0805 SM: 2635.0805
# [+]Comparing RTE: 2635.0900 SM: 2635.0900
# 	[+]Operations equal.: 2635.0900 SM: 2635.0900
# [+]Comparing RTE: 2640.1000 SM: 2640.1000
# 	[+]Operations equal.: 2640.1000 SM: 2640.1000
# [+]Comparing RTE: 2640.2000 SM: 2640.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2640.3000 SM: 2640.3000
# 	[+]Operations equal.: 2640.3000 SM: 2640.3000
# [+]Comparing RTE: 2640.3600 SM: 2640.3600
# 	[+]Operations equal.: 2640.3600 SM: 2640.3600
# [+]Comparing RTE: 2640.3700 SM: 2640.3700
# 	[+]Operations equal.: 2640.3700 SM: 2640.3700
# [+]Comparing RTE: 2640.3705 SM: 2640.3705
# 	[+]Operations equal.: 2640.3705 SM: 2640.3705
# [+]Comparing RTE: 2643.2002 SM: 2643.2002
# 	[+]Operations equal.: 2643.2002 SM: 2643.2002
# [+]Comparing RTE: 2643.3002 SM: 2643.3002
# 	[+]Operations equal.: 2643.3002 SM: 2643.3002
# [+]Comparing RTE: 2643.4002 SM: 2643.4002
# 	[+]Operations equal.: 2643.4002 SM: 2643.4002
# [+]Comparing RTE: 2643.4005 SM: 2643.4005
# 	[+]Operations equal.: 2643.4005 SM: 2643.4005
# [+]Comparing RTE: 2643.4010 SM: 2643.4010
# 	[+]Operations equal.: 2643.4010 SM: 2643.4010
# [+]Comparing RTE: 2643.5002 SM: 2643.5002
# 	[+]Operations equal.: 2643.5002 SM: 2643.5002
# [+]Comparing RTE: 2644.6002 SM: 2644.6002
# 	[+]Operations equal.: 2644.6002 SM: 2644.6002
# [+]Comparing RTE: 2644.7002 SM: 2644.7002
# 	[+]Operations equal.: 2644.7002 SM: 2644.7002
# [+]Comparing RTE: 2644.8002 SM: 2644.8002
# 	[+]Operations equal.: 2644.8002 SM: 2644.8002
# [+]Comparing RTE: 2644.8005 SM: 2644.8005
# 	[+]Operations equal.: 2644.8005 SM: 2644.8005
# [+]Comparing RTE: 2645.0200 SM: 2645.0200
# 	[+]Operations equal.: 2645.0200 SM: 2645.0200
# [+]Comparing RTE: 2645.0220 SM: 2645.0220
# 	[+]Operations equal.: 2645.0220 SM: 2645.0220
# [+]Comparing RTE: 2645.0240 SM: 2645.0240
# 	[+]Operations equal.: 2645.0240 SM: 2645.0240
# [+]Comparing RTE: 2645.0260 SM: 2645.0260
# 	[+]Operations equal.: 2645.0260 SM: 2645.0260
# [+]Comparing RTE: 2645.0280 SM: 2645.0280
# 	[+]Operations equal.: 2645.0280 SM: 2645.0280
# [+]Comparing RTE: 2647.1000 SM: 2647.1000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2647.2000 SM: 2647.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2647.3000 SM: 2647.3000
# 	[+]Operations equal.: 2647.3000 SM: 2647.3000
# [+]Comparing RTE: 2647.6000 SM: 2647.6000
# 	[+]Operations equal.: 2647.6000 SM: 2647.6000
# [+]Comparing RTE: 2647.7000 SM: 2647.7000
# 	[+]Operations equal.: 2647.7000 SM: 2647.7000
# [+]Comparing RTE: 2647.8000 SM: 2647.8000
# 	[+]Operations equal.: 2647.8000 SM: 2647.8000
# [+]Comparing RTE: 2650.3003 SM: 2650.3003
# 	[+]Operations equal.: 2650.3003 SM: 2650.3003
# [+]Comparing RTE: 2650.4003 SM: 2650.4003
# 	[+]Operations equal.: 2650.4003 SM: 2650.4003
# [+]Comparing RTE: 2650.4500 SM: 2650.4500
# 	[+]Operations equal.: 2650.4500 SM: 2650.4500
# [+]Comparing RTE: 2650.5003 SM: 2650.5003
# 	[+]Operations equal.: 2650.5003 SM: 2650.5003
# [+]Comparing RTE: 2650.7003 SM: 2650.7003
# 	[+]Operations equal.: 2650.7003 SM: 2650.7003
# [+]Comparing RTE: 2650.8003 SM: 2650.8003
# 	[+]Operations equal.: 2650.8003 SM: 2650.8003
# [+]Comparing RTE: 2650.9003 SM: 2650.9003
# 	[+]Operations equal.: 2650.9003 SM: 2650.9003
# [+]Comparing RTE: 2655.0600 SM: 2655.0600
# 	[+]Operations equal.: 2655.0600 SM: 2655.0600
# [+]Comparing RTE: 2660.1000 SM: 2660.1000
# 	[+]Operations equal.: 2660.1000 SM: 2660.1000
# [+]Comparing RTE: 2660.1100 SM: 2660.1100
# 	[+]Operations equal.: 2660.1100 SM: 2660.1100
# [+]Comparing RTE: 2660.1200 SM: 2660.1200
# 	[+]Operations equal.: 2660.1200 SM: 2660.1200
# [+]Comparing RTE: 2665.1200 SM: 2665.1200
# 	[+]Operations equal.: 2665.1200 SM: 2665.1200
# [+]Comparing RTE: 2665.1250 SM: 2665.1250
# 	[+]Operations equal.: 2665.1250 SM: 2665.1250
# [+]Comparing RTE: 2665.1300 SM: 2665.1300
# 	[+]Operations equal.: 2665.1300 SM: 2665.1300
# [+]Comparing RTE: 2670.2000 SM: 2670.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2670.2001 SM: 2670.2001
# 	[+]Operations equal.: 2670.2001 SM: 2670.2001
# [+]Comparing RTE: 2670.2050 SM: 2670.2050
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2670.2051 SM: 2670.2051
# 	[+]Operations equal.: 2670.2051 SM: 2670.2051
# [+]Comparing RTE: 2670.3000 SM: 2670.3000
# 	[+]Operations equal.: 2670.3000 SM: 2670.3000
# [+]Comparing RTE: 2675.4000 SM: 2675.4000
# 	[+]Operations equal.: 2675.4000 SM: 2675.4000
# [+]Comparing RTE: 2675.4001 SM: 2675.4001
# 	[+]Operations equal.: 2675.4001 SM: 2675.4001
# [+]Comparing RTE: 2675.5000 SM: 2675.5000
# 	[+]Operations equal.: 2675.5000 SM: 2675.5000
# [+]Comparing RTE: 2680.0750 SM: 2680.0750
# 	[+]Operations equal.: 2680.0750 SM: 2680.0750
# [+]Comparing RTE: 2680.0850 SM: 2680.0850
# 	[+]Operations equal.: 2680.0850 SM: 2680.0850
# [+]Comparing RTE: 2680.0950 SM: 2680.0950
# 	[+]Operations equal.: 2680.0950 SM: 2680.0950
# [+]Comparing RTE: 2680.1050 SM: 2680.1050
# 	[+]Operations equal.: 2680.1050 SM: 2680.1050
# [+]Comparing RTE: 2680.1150 SM: 2680.1150
# 	[+]Operations equal.: 2680.1150 SM: 2680.1150
# [+]Comparing RTE: 2685.3700 SM: 2685.3700
# 	[+]Operations equal.: 2685.3700 SM: 2685.3700
# [+]Comparing RTE: 2685.3800 SM: 2685.3800
# 	[+]Operations equal.: 2685.3800 SM: 2685.3800
# [+]Comparing RTE: 2685.3900 SM: 2685.3900
# 	[+]Operations equal.: 2685.3900 SM: 2685.3900
# [+]Comparing RTE: 2685.3901 SM: 2685.3901
# 	[+]Operations equal.: 2685.3901 SM: 2685.3901
# [+]Comparing RTE: 2685.4300 SM: 2685.4300
# 	[+]Operations equal.: 2685.4300 SM: 2685.4300
# [+]Comparing RTE: 2690.1010 SM: 2690.1010
# 	[+]Operations equal.: 2690.1010 SM: 2690.1010
# [+]Comparing RTE: 2690.1015 SM: 2690.1015
# 	[+]Operations equal.: 2690.1015 SM: 2690.1015
# [+]Comparing RTE: 2690.1020 SM: 2690.1020
# 	[+]Operations equal.: 2690.1020 SM: 2690.1020
# [+]Comparing RTE: 2690.1030 SM: 2690.1030
# 	[+]Operations equal.: 2690.1030 SM: 2690.1030
# [+]Comparing RTE: 2690.1040 SM: 2690.1040
# 	[+]Operations equal.: 2690.1040 SM: 2690.1040
# [+]Comparing RTE: 2695.0500 SM: 2695.0500
# 	[+]Operations equal.: 2695.0500 SM: 2695.0500
# [+]Comparing RTE: 2695.0600 SM: 2695.0600
# 	[+]Operations equal.: 2695.0600 SM: 2695.0600
# [+]Comparing RTE: 2695.0700 SM: 2695.0700
# 	[+]Operations equal.: 2695.0700 SM: 2695.0700
# [+]Comparing RTE: 2695.0750 SM: 2695.0750
# 	[+]Operations equal.: 2695.0750 SM: 2695.0750
# [+]Comparing RTE: 2695.0800 SM: 2695.0800
# 	[+]Operations equal.: 2695.0800 SM: 2695.0800
# [+]Comparing RTE: 2695.0805 SM: 2695.0805
# 	[+]Operations equal.: 2695.0805 SM: 2695.0805
# [+]Comparing RTE: 2695.0900 SM: 2695.0900
# 	[+]Operations equal.: 2695.0900 SM: 2695.0900
# [+]Comparing RTE: 2700.1000 SM: 2700.1000
# 	[+]Operations equal.: 2700.1000 SM: 2700.1000
# [+]Comparing RTE: 2700.2000 SM: 2700.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2700.3000 SM: 2700.3000
# 	[+]Operations equal.: 2700.3000 SM: 2700.3000
# [+]Comparing RTE: 2700.6000 SM: 2700.6000
# 	[+]Operations equal.: 2700.6000 SM: 2700.6000
# [+]Comparing RTE: 2700.7000 SM: 2700.7000
# 	[+]Operations equal.: 2700.7000 SM: 2700.7000
# [+]Comparing RTE: 2700.8000 SM: 2700.8000
# 	[+]Operations equal.: 2700.8000 SM: 2700.8000
# [+]Comparing RTE: 2705.3003 SM: 2705.3003
# 	[+]Operations equal.: 2705.3003 SM: 2705.3003
# [+]Comparing RTE: 2705.4003 SM: 2705.4003
# 	[+]Operations equal.: 2705.4003 SM: 2705.4003
# [+]Comparing RTE: 2705.5003 SM: 2705.5003
# 	[+]Operations equal.: 2705.5003 SM: 2705.5003
# [+]Comparing RTE: 2705.5005 SM: 2705.5005
# 	[+]Operations equal.: 2705.5005 SM: 2705.5005
# [+]Comparing RTE: 2705.5010 SM: 2705.5010
# 	[+]Operations equal.: 2705.5010 SM: 2705.5010
# [+]Comparing RTE: 2708.6003 SM: 2708.6003
# 	[+]Operations equal.: 2708.6003 SM: 2708.6003
# [+]Comparing RTE: 2708.7003 SM: 2708.7003
# 	[+]Operations equal.: 2708.7003 SM: 2708.7003
# [+]Comparing RTE: 2708.7005 SM: 2708.7005
# 	[+]Operations equal.: 2708.7005 SM: 2708.7005
# [+]Comparing RTE: 2710.0200 SM: 2710.0200
# 	[+]Operations equal.: 2710.0200 SM: 2710.0200
# [+]Comparing RTE: 2710.0220 SM: 2710.0220
# 	[+]Operations equal.: 2710.0220 SM: 2710.0220
# [+]Comparing RTE: 2710.0240 SM: 2710.0240
# 	[+]Operations equal.: 2710.0240 SM: 2710.0240
# [+]Comparing RTE: 2710.0260 SM: 2710.0260
# 	[+]Operations equal.: 2710.0260 SM: 2710.0260
# [+]Comparing RTE: 2710.0280 SM: 2710.0280
# 	[+]Operations equal.: 2710.0280 SM: 2710.0280
# [+]Comparing RTE: 2715.1000 SM: 2715.1000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2715.2000 SM: 2715.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2715.3000 SM: 2715.3000
# 	[+]Operations equal.: 2715.3000 SM: 2715.3000
# [+]Comparing RTE: 2715.6000 SM: 2715.6000
# 	[+]Operations equal.: 2715.6000 SM: 2715.6000
# [+]Comparing RTE: 2715.7000 SM: 2715.7000
# 	[+]Operations equal.: 2715.7000 SM: 2715.7000
# [+]Comparing RTE: 2715.8000 SM: 2715.8000
# 	[+]Operations equal.: 2715.8000 SM: 2715.8000
# [+]Comparing RTE: 2720.0500 SM: 2720.0500
# 	[+]Operations equal.: 2720.0500 SM: 2720.0500
# [+]Comparing RTE: 2720.1000 SM: 2720.1000
# 	[+]Operations equal.: 2720.1000 SM: 2720.1000
# [+]Comparing RTE: 2720.1200 SM: 2720.1200
# 	[+]Operations equal.: 2720.1200 SM: 2720.1200
# [+]Comparing RTE: 2720.1500 SM: 2720.1500
# 	[+]Operations equal.: 2720.1500 SM: 2720.1500
# [+]Comparing RTE: 2720.2500 SM: 2720.2500
# 	[+]Operations equal.: 2720.2500 SM: 2720.2500
# [+]Comparing RTE: 2720.3000 SM: 2720.3000
# 	[+]Operations equal.: 2720.3000 SM: 2720.3000
# [+]Comparing RTE: 2720.3500 SM: 2720.3500
# 	[+]Operations equal.: 2720.3500 SM: 2720.3500
# [+]Comparing RTE: 2725.0200 SM: 2725.0200
# 	[+]Operations equal.: 2725.0200 SM: 2725.0200
# [+]Comparing RTE: 2730.0200 SM: 2730.0200
# 	[+]Operations equal.: 2730.0200 SM: 2730.0200
# [+]Comparing RTE: 2730.0400 SM: 2730.0400
# 	[+]Operations equal.: 2730.0400 SM: 2730.0400
# [+]Comparing RTE: 2730.0600 SM: 2730.0600
# 	[+]Operations equal.: 2730.0600 SM: 2730.0600
# [+]Comparing RTE: 2735.1200 SM: 2735.1200
# 	[+]Operations equal.: 2735.1200 SM: 2735.1200
# [+]Comparing RTE: 2735.1250 SM: 2735.1250
# 	[+]Operations equal.: 2735.1250 SM: 2735.1250
# [+]Comparing RTE: 2735.1300 SM: 2735.1300
# 	[+]Operations equal.: 2735.1300 SM: 2735.1300
# [+]Comparing RTE: 2740.2000 SM: 2740.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2740.2001 SM: 2740.2001
# 	[+]Operations equal.: 2740.2001 SM: 2740.2001
# [+]Comparing RTE: 2740.2050 SM: 2740.2050
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2740.2051 SM: 2740.2051
# 	[+]Operations equal.: 2740.2051 SM: 2740.2051
# [+]Comparing RTE: 2740.3000 SM: 2740.3000
# 	[+]Operations equal.: 2740.3000 SM: 2740.3000
# [+]Comparing RTE: 2745.4000 SM: 2745.4000
# 	[+]Operations equal.: 2745.4000 SM: 2745.4000
# [+]Comparing RTE: 2745.5000 SM: 2745.5000
# 	[+]Operations equal.: 2745.5000 SM: 2745.5000
# [+]Comparing RTE: 2745.6000 SM: 2745.6000
# 	[+]Operations equal.: 2745.6000 SM: 2745.6000
# [+]Comparing RTE: 2785.0750 SM: 2785.0750
# 	[+]Operations equal.: 2785.0750 SM: 2785.0750
# [+]Comparing RTE: 2785.0850 SM: 2785.0850
# 	[+]Operations equal.: 2785.0850 SM: 2785.0850
# [+]Comparing RTE: 2785.0950 SM: 2785.0950
# 	[+]Operations equal.: 2785.0950 SM: 2785.0950
# [+]Comparing RTE: 2785.1050 SM: 2785.1050
# 	[+]Operations equal.: 2785.1050 SM: 2785.1050
# [+]Comparing RTE: 2785.1150 SM: 2785.1150
# 	[+]Operations equal.: 2785.1150 SM: 2785.1150
# [+]Comparing RTE: 2790.3700 SM: 2790.3700
# 	[+]Operations equal.: 2790.3700 SM: 2790.3700
# [+]Comparing RTE: 2790.3800 SM: 2790.3800
# 	[+]Operations equal.: 2790.3800 SM: 2790.3800
# [+]Comparing RTE: 2790.3900 SM: 2790.3900
# 	[+]Operations equal.: 2790.3900 SM: 2790.3900
# [+]Comparing RTE: 2790.3901 SM: 2790.3901
# 	[+]Operations equal.: 2790.3901 SM: 2790.3901
# [+]Comparing RTE: 2790.4300 SM: 2790.4300
# 	[+]Operations equal.: 2790.4300 SM: 2790.4300
# [+]Comparing RTE: 2795.1010 SM: 2795.1010
# 	[+]Operations equal.: 2795.1010 SM: 2795.1010
# [+]Comparing RTE: 2795.1015 SM: 2795.1015
# 	[+]Operations equal.: 2795.1015 SM: 2795.1015
# [+]Comparing RTE: 2795.1020 SM: 2795.1020
# 	[+]Operations equal.: 2795.1020 SM: 2795.1020
# [+]Comparing RTE: 2795.1030 SM: 2795.1030
# 	[+]Operations equal.: 2795.1030 SM: 2795.1030
# [+]Comparing RTE: 2795.1040 SM: 2795.1040
# 	[+]Operations equal.: 2795.1040 SM: 2795.1040
# [+]Comparing RTE: 2800.0500 SM: 2800.0500
# 	[+]Operations equal.: 2800.0500 SM: 2800.0500
# [+]Comparing RTE: 2800.0600 SM: 2800.0600
# 	[+]Operations equal.: 2800.0600 SM: 2800.0600
# [+]Comparing RTE: 2800.0605 SM: 2800.0605
# 	[+]Operations equal.: 2800.0605 SM: 2800.0605
# [+]Comparing RTE: 2800.0700 SM: 2800.0700
# 	[+]Operations equal.: 2800.0700 SM: 2800.0700
# [+]Comparing RTE: 2800.0750 SM: 2800.0750
# 	[+]Operations equal.: 2800.0750 SM: 2800.0750
# [+]Comparing RTE: 2800.0800 SM: 2800.0800
# 	[+]Operations equal.: 2800.0800 SM: 2800.0800
# [+]Comparing RTE: 2800.0805 SM: 2800.0805
# 	[+]Operations equal.: 2800.0805 SM: 2800.0805
# [+]Comparing RTE: 2800.0900 SM: 2800.0900
# 	[+]Operations equal.: 2800.0900 SM: 2800.0900
# [+]Comparing RTE: 2805.1000 SM: 2805.1000
# 	[+]Operations equal.: 2805.1000 SM: 2805.1000
# [+]Comparing RTE: 2805.2000 SM: 2805.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2805.3000 SM: 2805.3000
# 	[+]Operations equal.: 2805.3000 SM: 2805.3000
# [+]Comparing RTE: 2805.4000 SM: 2805.4000
# 	[+]Operations equal.: 2805.4000 SM: 2805.4000
# [+]Comparing RTE: 2805.5000 SM: 2805.5000
# 	[+]Operations equal.: 2805.5000 SM: 2805.5000
# [+]Comparing RTE: 2805.6000 SM: 2805.6000
# 	[+]Operations equal.: 2805.6000 SM: 2805.6000
# [+]Comparing RTE: 2805.7000 SM: 2805.7000
# 	[+]Operations equal.: 2805.7000 SM: 2805.7000
# [+]Comparing RTE: 2805.8000 SM: 2805.8000
# 	[+]Operations equal.: 2805.8000 SM: 2805.8000
# [+]Comparing RTE: 2810.3003 SM: 2810.3003
# 	[+]Operations equal.: 2810.3003 SM: 2810.3003
# [+]Comparing RTE: 2810.4003 SM: 2810.4003
# 	[+]Operations equal.: 2810.4003 SM: 2810.4003
# [+]Comparing RTE: 2810.5003 SM: 2810.5003
# 	[+]Operations equal.: 2810.5003 SM: 2810.5003
# [+]Comparing RTE: 2813.6003 SM: 2813.6003
# 	[+]Operations equal.: 2813.6003 SM: 2813.6003
# [+]Comparing RTE: 2813.7003 SM: 2813.7003
# 	[+]Operations equal.: 2813.7003 SM: 2813.7003
# [+]Comparing RTE: 2813.8003 SM: 2813.8003
# 	[+]Operations equal.: 2813.8003 SM: 2813.8003
# [+]Comparing RTE: 2815.0200 SM: 2815.0200
# 	[+]Operations equal.: 2815.0200 SM: 2815.0200
# [+]Comparing RTE: 2815.0220 SM: 2815.0220
# 	[+]Operations equal.: 2815.0220 SM: 2815.0220
# [+]Comparing RTE: 2815.0240 SM: 2815.0240
# 	[+]Operations equal.: 2815.0240 SM: 2815.0240
# [+]Comparing RTE: 2815.0260 SM: 2815.0260
# 	[+]Operations equal.: 2815.0260 SM: 2815.0260
# [+]Comparing RTE: 2815.0280 SM: 2815.0280
# 	[+]Operations equal.: 2815.0280 SM: 2815.0280
# [+]Comparing RTE: 2820.1000 SM: 2820.1000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2820.2000 SM: 2820.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2820.3000 SM: 2820.3000
# 	[+]Operations equal.: 2820.3000 SM: 2820.3000
# [+]Comparing RTE: 2820.4000 SM: 2820.4000
# 	[+]Operations equal.: 2820.4000 SM: 2820.4000
# [+]Comparing RTE: 2820.5000 SM: 2820.5000
# 	[+]Operations equal.: 2820.5000 SM: 2820.5000
# [+]Comparing RTE: 2820.6000 SM: 2820.6000
# 	[+]Operations equal.: 2820.6000 SM: 2820.6000
# [+]Comparing RTE: 2820.7000 SM: 2820.7000
# 	[+]Operations equal.: 2820.7000 SM: 2820.7000
# [+]Comparing RTE: 2820.8000 SM: 2820.8000
# 	[+]Operations equal.: 2820.8000 SM: 2820.8000
# [+]Comparing RTE: 2825.0500 SM: 2825.0500
# 	[+]Operations equal.: 2825.0500 SM: 2825.0500
# [+]Comparing RTE: 2825.1000 SM: 2825.1000
# 	[+]Operations equal.: 2825.1000 SM: 2825.1000
# [+]Comparing RTE: 2825.1200 SM: 2825.1200
# 	[+]Operations equal.: 2825.1200 SM: 2825.1200
# [+]Comparing RTE: 2825.1500 SM: 2825.1500
# 	[+]Operations equal.: 2825.1500 SM: 2825.1500
# [+]Comparing RTE: 2825.2000 SM: 2825.2000
# 	[+]Operations equal.: 2825.2000 SM: 2825.2000
# [+]Comparing RTE: 2825.2500 SM: 2825.2500
# 	[+]Operations equal.: 2825.2500 SM: 2825.2500
# [+]Comparing RTE: 2825.3000 SM: 2825.3000
# 	[+]Operations equal.: 2825.3000 SM: 2825.3000
# [+]Comparing RTE: 2825.3500 SM: 2825.3500
# 	[+]Operations equal.: 2825.3500 SM: 2825.3500
# [+]Comparing RTE: 2830.0200 SM: 2830.0200
# 	[+]Operations equal.: 2830.0200 SM: 2830.0200
# [+]Comparing RTE: 2835.0200 SM: 2835.0200
# 	[+]Operations equal.: 2835.0200 SM: 2835.0200
# [+]Comparing RTE: 2835.0400 SM: 2835.0400
# 	[+]Operations equal.: 2835.0400 SM: 2835.0400
# [+]Comparing RTE: 2835.0600 SM: 2835.0600
# 	[+]Operations equal.: 2835.0600 SM: 2835.0600
# [+]Comparing RTE: 2840.1200 SM: 2840.1200
# 	[+]Operations equal.: 2840.1200 SM: 2840.1200
# [+]Comparing RTE: 2840.1250 SM: 2840.1250
# 	[+]Operations equal.: 2840.1250 SM: 2840.1250
# [+]Comparing RTE: 2840.1300 SM: 2840.1300
# 	[+]Operations equal.: 2840.1300 SM: 2840.1300
# [+]Comparing RTE: 2845.2000 SM: 2845.2000
# 	[+]Operations equal.: 2845.2000 SM: 2845.2000
# [+]Comparing RTE: 2845.2001 SM: 2845.2001
# 	[+]Operations equal.: 2845.2001 SM: 2845.2001
# [+]Comparing RTE: 2845.2050 SM: 2845.2050
# 	[+]Operations equal.: 2845.2050 SM: 2845.2050
# [+]Comparing RTE: 2845.2051 SM: 2845.2051
# 	[+]Operations equal.: 2845.2051 SM: 2845.2051
# [+]Comparing RTE: 2845.3000 SM: 2845.3000
# 	[+]Operations equal.: 2845.3000 SM: 2845.3000
# [+]Comparing RTE: 2850.4000 SM: 2850.4000
# 	[+]Operations equal.: 2850.4000 SM: 2850.4000
# [+]Comparing RTE: 2850.5000 SM: 2850.5000
# 	[+]Operations equal.: 2850.5000 SM: 2850.5000
# [+]Comparing RTE: 2850.6000 SM: 2850.6000
# 	[+]Operations equal.: 2850.6000 SM: 2850.6000
# [+]Comparing RTE: 2850.7000 SM: 2850.7000
# 	[+]Operations equal.: 2850.7000 SM: 2850.7000
# [+]Comparing RTE: 2885.0750 SM: 2885.0750
# 	[+]Operations equal.: 2885.0750 SM: 2885.0750
# [+]Comparing RTE: 2885.0850 SM: 2885.0850
# 	[+]Operations equal.: 2885.0850 SM: 2885.0850
# [+]Comparing RTE: 2885.0950 SM: 2885.0950
# 	[+]Operations equal.: 2885.0950 SM: 2885.0950
# [+]Comparing RTE: 2885.1050 SM: 2885.1050
# 	[+]Operations equal.: 2885.1050 SM: 2885.1050
# [+]Comparing RTE: 2885.1150 SM: 2885.1150
# 	[+]Operations equal.: 2885.1150 SM: 2885.1150
# [+]Comparing RTE: 2890.3700 SM: 2890.3700
# 	[+]Operations equal.: 2890.3700 SM: 2890.3700
# [+]Comparing RTE: 2890.3800 SM: 2890.3800
# 	[+]Operations equal.: 2890.3800 SM: 2890.3800
# [+]Comparing RTE: 2890.3900 SM: 2890.3900
# 	[+]Operations equal.: 2890.3900 SM: 2890.3900
# [+]Comparing RTE: 2890.3901 SM: 2890.3901
# 	[+]Operations equal.: 2890.3901 SM: 2890.3901
# [+]Comparing RTE: 2890.4300 SM: 2890.4300
# 	[+]Operations equal.: 2890.4300 SM: 2890.4300
# [+]Comparing RTE: 2895.1010 SM: 2895.1010
# 	[+]Operations equal.: 2895.1010 SM: 2895.1010
# [+]Comparing RTE: 2895.1015 SM: 2895.1015
# 	[+]Operations equal.: 2895.1015 SM: 2895.1015
# [+]Comparing RTE: 2895.1020 SM: 2895.1020
# 	[+]Operations equal.: 2895.1020 SM: 2895.1020
# [+]Comparing RTE: 2895.1030 SM: 2895.1030
# 	[+]Operations equal.: 2895.1030 SM: 2895.1030
# [+]Comparing RTE: 2895.1040 SM: 2895.1040
# 	[+]Operations equal.: 2895.1040 SM: 2895.1040
# [+]Comparing RTE: 2900.0500 SM: 2900.0500
# 	[+]Operations equal.: 2900.0500 SM: 2900.0500
# [+]Comparing RTE: 2900.0600 SM: 2900.0600
# 	[+]Operations equal.: 2900.0600 SM: 2900.0600
# [+]Comparing RTE: 2900.0605 SM: 2900.0605
# 	[+]Operations equal.: 2900.0605 SM: 2900.0605
# [+]Comparing RTE: 2900.0700 SM: 2900.0700
# 	[+]Operations equal.: 2900.0700 SM: 2900.0700
# [+]Comparing RTE: 2900.0750 SM: 2900.0750
# 	[+]Operations equal.: 2900.0750 SM: 2900.0750
# [+]Comparing RTE: 2900.0800 SM: 2900.0800
# 	[+]Operations equal.: 2900.0800 SM: 2900.0800
# [+]Comparing RTE: 2900.0805 SM: 2900.0805
# 	[+]Operations equal.: 2900.0805 SM: 2900.0805
# [+]Comparing RTE: 2900.0900 SM: 2900.0900
# 	[+]Operations equal.: 2900.0900 SM: 2900.0900
# [+]Comparing RTE: 2905.1000 SM: 2905.1000
# 	[+]Operations equal.: 2905.1000 SM: 2905.1000
# [+]Comparing RTE: 2905.2000 SM: 2905.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2905.3000 SM: 2905.3000
# 	[+]Operations equal.: 2905.3000 SM: 2905.3000
# [+]Comparing RTE: 2905.4000 SM: 2905.4000
# 	[+]Operations equal.: 2905.4000 SM: 2905.4000
# [+]Comparing RTE: 2905.5000 SM: 2905.5000
# 	[+]Operations equal.: 2905.5000 SM: 2905.5000
# [+]Comparing RTE: 2905.6000 SM: 2905.6000
# 	[+]Operations equal.: 2905.6000 SM: 2905.6000
# [+]Comparing RTE: 2905.7000 SM: 2905.7000
# 	[+]Operations equal.: 2905.7000 SM: 2905.7000
# [+]Comparing RTE: 2905.8000 SM: 2905.8000
# 	[+]Operations equal.: 2905.8000 SM: 2905.8000
# [+]Comparing RTE: 2910.3003 SM: 2910.3003
# 	[+]Operations equal.: 2910.3003 SM: 2910.3003
# [+]Comparing RTE: 2910.4003 SM: 2910.4003
# 	[+]Operations equal.: 2910.4003 SM: 2910.4003
# [+]Comparing RTE: 2910.5003 SM: 2910.5003
# 	[+]Operations equal.: 2910.5003 SM: 2910.5003
# [+]Comparing RTE: 2913.6003 SM: 2913.6003
# 	[+]Operations equal.: 2913.6003 SM: 2913.6003
# [+]Comparing RTE: 2913.7003 SM: 2913.7003
# 	[+]Operations equal.: 2913.7003 SM: 2913.7003
# [+]Comparing RTE: 2913.8003 SM: 2913.8003
# 	[+]Operations equal.: 2913.8003 SM: 2913.8003
# [+]Comparing RTE: 2915.0200 SM: 2915.0200
# 	[+]Operations equal.: 2915.0200 SM: 2915.0200
# [+]Comparing RTE: 2915.0220 SM: 2915.0220
# 	[+]Operations equal.: 2915.0220 SM: 2915.0220
# [+]Comparing RTE: 2915.0240 SM: 2915.0240
# 	[+]Operations equal.: 2915.0240 SM: 2915.0240
# [+]Comparing RTE: 2915.0260 SM: 2915.0260
# 	[+]Operations equal.: 2915.0260 SM: 2915.0260
# [+]Comparing RTE: 2915.0280 SM: 2915.0280
# 	[+]Operations equal.: 2915.0280 SM: 2915.0280
# [+]Comparing RTE: 2920.1000 SM: 2920.1000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2920.2000 SM: 2920.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2920.3000 SM: 2920.3000
# 	[+]Operations equal.: 2920.3000 SM: 2920.3000
# [+]Comparing RTE: 2920.4000 SM: 2920.4000
# 	[+]Operations equal.: 2920.4000 SM: 2920.4000
# [+]Comparing RTE: 2920.5000 SM: 2920.5000
# 	[+]Operations equal.: 2920.5000 SM: 2920.5000
# [+]Comparing RTE: 2920.6000 SM: 2920.6000
# 	[+]Operations equal.: 2920.6000 SM: 2920.6000
# [+]Comparing RTE: 2920.7000 SM: 2920.7000
# 	[+]Operations equal.: 2920.7000 SM: 2920.7000
# [+]Comparing RTE: 2920.8000 SM: 2920.8000
# 	[+]Operations equal.: 2920.8000 SM: 2920.8000
# [+]Comparing RTE: 2925.0500 SM: 2925.0500
# 	[+]Operations equal.: 2925.0500 SM: 2925.0500
# [+]Comparing RTE: 2925.1000 SM: 2925.1000
# 	[+]Operations equal.: 2925.1000 SM: 2925.1000
# [+]Comparing RTE: 2925.1200 SM: 2925.1200
# 	[+]Operations equal.: 2925.1200 SM: 2925.1200
# [+]Comparing RTE: 2925.1500 SM: 2925.1500
# 	[+]Operations equal.: 2925.1500 SM: 2925.1500
# [+]Comparing RTE: 2925.2000 SM: 2925.2000
# 	[+]Operations equal.: 2925.2000 SM: 2925.2000
# [+]Comparing RTE: 2925.2500 SM: 2925.2500
# 	[+]Operations equal.: 2925.2500 SM: 2925.2500
# [+]Comparing RTE: 2925.3000 SM: 2925.3000
# 	[+]Operations equal.: 2925.3000 SM: 2925.3000
# [+]Comparing RTE: 2925.3500 SM: 2925.3500
# 	[+]Operations equal.: 2925.3500 SM: 2925.3500
# [+]Comparing RTE: 2930.0200 SM: 2930.0200
# 	[+]Operations equal.: 2930.0200 SM: 2930.0200
# [+]Comparing RTE: 2935.0200 SM: 2935.0200
# 	[+]Operations equal.: 2935.0200 SM: 2935.0200
# [+]Comparing RTE: 2935.0400 SM: 2935.0400
# 	[+]Operations equal.: 2935.0400 SM: 2935.0400
# [+]Comparing RTE: 2935.0600 SM: 2935.0600
# 	[+]Operations equal.: 2935.0600 SM: 2935.0600
# [+]Comparing RTE: 2940.1200 SM: 2940.1200
# 	[+]Operations equal.: 2940.1200 SM: 2940.1200
# [+]Comparing RTE: 2940.1250 SM: 2940.1250
# 	[+]Operations equal.: 2940.1250 SM: 2940.1250
# [+]Comparing RTE: 2940.1300 SM: 2940.1300
# 	[+]Operations equal.: 2940.1300 SM: 2940.1300
# [+]Comparing RTE: 2945.2000 SM: 2945.2000
# 	[+]Operations equal.: 2945.2000 SM: 2945.2000
# [+]Comparing RTE: 2945.2001 SM: 2945.2001
# 	[+]Operations equal.: 2945.2001 SM: 2945.2001
# [+]Comparing RTE: 2945.2050 SM: 2945.2050
# 	[+]Operations equal.: 2945.2050 SM: 2945.2050
# [+]Comparing RTE: 2945.2051 SM: 2945.2051
# 	[+]Operations equal.: 2945.2051 SM: 2945.2051
# [+]Comparing RTE: 2945.3000 SM: 2945.3000
# 	[+]Operations equal.: 2945.3000 SM: 2945.3000
# [+]Comparing RTE: 2950.4000 SM: 2950.4000
# 	[+]Operations equal.: 2950.4000 SM: 2950.4000
# [+]Comparing RTE: 2950.5000 SM: 2950.5000
# 	[+]Operations equal.: 2950.5000 SM: 2950.5000
# [+]Comparing RTE: 2950.6000 SM: 2950.6000
# 	[+]Operations equal.: 2950.6000 SM: 2950.6000
# [+]Comparing RTE: 2950.7000 SM: 2950.7000
# 	[+]Operations equal.: 2950.7000 SM: 2950.7000
# [+]Comparing RTE: 2955.1000 SM: 2955.1000
# 	[+]Operations equal.: 2955.1000 SM: 2955.1000
# [+]Comparing RTE: 2955.2000 SM: 2955.2000
# 	[+]Operations equal.: 2955.2000 SM: 2955.2000
# [+]Comparing RTE: 2955.2100 SM: 2955.2100
# 	[+]Operations equal.: 2955.2100 SM: 2955.2100
# [+]Comparing RTE: 2955.2200 SM: 2955.2200
# 	[+]Operations equal.: 2955.2200 SM: 2955.2200
# [+]Comparing RTE: 2955.3000 SM: 2955.3000
# 	[+]Operations equal.: 2955.3000 SM: 2955.3000
# [+]Comparing RTE: 2960.1000 SM: 2960.1000
# 	[+]Operations equal.: 2960.1000 SM: 2960.1000
# [+]Comparing RTE: 2960.1200 SM: 2960.1200
# 	[+]Operations equal.: 2960.1200 SM: 2960.1200
# [+]Comparing RTE: 2960.2000 SM: 2960.2000
# 	[+]Operations equal.: 2960.2000 SM: 2960.2000
# [+]Comparing RTE: 2965.1000 SM: 2965.1000
# 	[+]Operations equal.: 2965.1000 SM: 2965.1000
# [+]Comparing RTE: 2965.2000 SM: 2965.2000
# 	[+]Operations equal.: 2965.2000 SM: 2965.2000
# [+]Comparing RTE: 2970.1000 SM: 2970.1000
# 	[+]Operations equal.: 2970.1000 SM: 2970.1000
# [+]Comparing RTE: 2970.1100 SM: 2970.1100
# 	[+]Operations equal.: 2970.1100 SM: 2970.1100
# [+]Comparing RTE: 2970.2000 SM: 2970.2000
# 	[+]Operations equal.: 2970.2000 SM: 2970.2000
# [+]Comparing RTE: 2975.1000 SM: 2975.1000
# 	[+]Operations equal.: 2975.1000 SM: 2975.1000
# [+]Comparing RTE: 2975.2000 SM: 2975.2000
# 	[+]Operations equal.: 2975.2000 SM: 2975.2000
# [+]Comparing RTE: 2980.1000 SM: 2980.1000
# 	[+]Operations equal.: 2980.1000 SM: 2980.1000
# [+]Comparing RTE: 2985.1000 SM: 2985.1000
# 	[+]Operations equal.: 2985.1000 SM: 2985.1000
# [+]Comparing RTE: 2985.1100 SM: 2985.1100
# 	[+]Operations equal.: 2985.1100 SM: 2985.1100
# [+]Comparing RTE: 2985.1200 SM: 2985.1200
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 2985.1300 SM: 2985.1300
# 	[+]Operations equal.: 2985.1300 SM: 2985.1300
# [+]Comparing RTE: 2990.1000 SM: 2990.1000
# 	[+]Operations equal.: 2990.1000 SM: 2990.1000
# [+]Comparing RTE: 2990.2000 SM: 2990.2000
# 	[+]Operations equal.: 2990.2000 SM: 2990.2000
# [+]Comparing RTE: 2990.3000 SM: 2990.3000
# 	[+]Operations equal.: 2990.3000 SM: 2990.3000
# [+]Comparing RTE: 2990.3500 SM: 2990.3500
# 	[+]Operations equal.: 2990.3500 SM: 2990.3500
# [+]Comparing RTE: 2995.1000 SM: 2995.1000
# 	[+]Operations equal.: 2995.1000 SM: 2995.1000
# [+]Comparing RTE: 3000.1000 SM: 3000.1000
# 	[+]Operations equal.: 3000.1000 SM: 3000.1000
# [+]Comparing RTE: 3000.4000 SM: 3000.4000
# 	[+]Operations equal.: 3000.4000 SM: 3000.4000
# [+]Comparing RTE: 3000.5000 SM: 3000.5000
# 	[+]Operations equal.: 3000.5000 SM: 3000.5000
# [+]Comparing RTE: 3005.1000 SM: 3005.1000
# 	[+]Operations equal.: 3005.1000 SM: 3005.1000
# [+]Comparing RTE: 3005.2000 SM: 3005.2000
# 	[+]Operations equal.: 3005.2000 SM: 3005.2000
# [+]Comparing RTE: 3010.1000 SM: 3010.1000
# 	[+]Operations equal.: 3010.1000 SM: 3010.1000
# [+]Comparing RTE: 3015.5000 SM: 3015.5000
# 	[+]Operations equal.: 3015.5000 SM: 3015.5000
# [+]Comparing RTE: 3015.5100 SM: 3015.5100
# 	[+]Operations equal.: 3015.5100 SM: 3015.5100
# [+]Comparing RTE: 3015.6000 SM: 3015.6000
# 	[+]Operations equal.: 3015.6000 SM: 3015.6000
# [+]Comparing RTE: 3015.6100 SM: 3015.6100
# 	[+]Operations equal.: 3015.6100 SM: 3015.6100
# [+]Comparing RTE: 3015.6200 SM: 3015.6200
# 	[+]Operations equal.: 3015.6200 SM: 3015.6200
# [+]Comparing RTE: 3015.7000 SM: 3015.7000
# 	[+]Operations equal.: 3015.7000 SM: 3015.7000
# [+]Comparing RTE: 3015.7100 SM: 3015.7100
# 	[+]Operations equal.: 3015.7100 SM: 3015.7100
# [+]Comparing RTE: 3020.8000 SM: 3020.8000
# 	[+]Operations equal.: 3020.8000 SM: 3020.8000
# [+]Comparing RTE: 3020.8100 SM: 3020.8100
# 	[+]Operations equal.: 3020.8100 SM: 3020.8100
# [+]Comparing RTE: 3020.8200 SM: 3020.8200
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 3020.8300 SM: 3020.8300
# 	[+]Operations equal.: 3020.8300 SM: 3020.8300
# [+]Comparing RTE: 3025.1000 SM: 3025.1000
# 	[+]Operations equal.: 3025.1000 SM: 3025.1000
# [+]Comparing RTE: 3025.2000 SM: 3025.2000
# 	[+]Operations equal.: 3025.2000 SM: 3025.2000
# [+]Comparing RTE: 3025.3000 SM: 3025.3000
# 	[+]Operations equal.: 3025.3000 SM: 3025.3000
# [+]Comparing RTE: 3025.3500 SM: 3025.3500
# 	[+]Operations equal.: 3025.3500 SM: 3025.3500
# [+]Comparing RTE: 3030.1000 SM: 3030.1000
# 	[+]Operations equal.: 3030.1000 SM: 3030.1000
# [+]Comparing RTE: 3030.2000 SM: 3030.2000
# 	[+]Operations equal.: 3030.2000 SM: 3030.2000
# [+]Comparing RTE: 3030.2020 SM: 3030.2020
# 	[+]Operations equal.: 3030.2020 SM: 3030.2020
# [+]Comparing RTE: 3030.2200 SM: 3030.2200
# 	[+]Operations equal.: 3030.2200 SM: 3030.2200
# [+]Comparing RTE: 3030.2250 SM: 3030.2250
# 	[+]Operations equal.: 3030.2250 SM: 3030.2250
# [+]Comparing RTE: 3030.2260 SM: 3030.2260
# 	[+]Operations equal.: 3030.2260 SM: 3030.2260
# [+]Comparing RTE: 3030.2300 SM: 3030.2300
# 	[+]Operations equal.: 3030.2300 SM: 3030.2300
# [+]Comparing RTE: 3030.2400 SM: 3030.2400
# 	[+]Operations equal.: 3030.2400 SM: 3030.2400
# [+]Comparing RTE: 3035.2500 SM: 3035.2500
# 	[+]Operations equal.: 3035.2500 SM: 3035.2500
# [+]Comparing RTE: 3035.3000 SM: 3035.3000
# 	[+]Operations equal.: 3035.3000 SM: 3035.3000
# [+]Comparing RTE: 3035.3100 SM: 3035.3100
# 	[+]Operations equal.: 3035.3100 SM: 3035.3100
# [+]Comparing RTE: 3035.3200 SM: 3035.3200
# 	[+]Operations equal.: 3035.3200 SM: 3035.3200
# [+]Comparing RTE: 3040.4000 SM: 3040.4000
# 	[+]Operations equal.: 3040.4000 SM: 3040.4000
# [+]Comparing RTE: 3040.4100 SM: 3040.4100
# 	[+]Operations equal.: 3040.4100 SM: 3040.4100
# [+]Comparing RTE: 3040.5000 SM: 3040.5000
# 	[+]Operations equal.: 3040.5000 SM: 3040.5000
# [+]Comparing RTE: 3040.6000 SM: 3040.6000
# 	[+]Operations equal.: 3040.6000 SM: 3040.6000
# [+]Comparing RTE: 3040.7000 SM: 3040.7000
# 	[+]Operations equal.: 3040.7000 SM: 3040.7000
# [+]Comparing RTE: 3045.1000 SM: 3045.1000
# 	[+]Operations equal.: 3045.1000 SM: 3045.1000
# [+]Comparing RTE: 3045.1020 SM: 3045.1020
# 	[+]Operations equal.: 3045.1020 SM: 3045.1020
# [+]Comparing RTE: 3045.1100 SM: 3045.1100
# 	[+]Operations equal.: 3045.1100 SM: 3045.1100
# [+]Comparing RTE: 3045.1110 SM: 3045.1110
# 	[+]Operations equal.: 3045.1110 SM: 3045.1110
# [+]Comparing RTE: 3045.1120 SM: 3045.1120
# 	[+]Operations equal.: 3045.1120 SM: 3045.1120
# [+]Comparing RTE: 3045.1200 SM: 3045.1200
# 	[+]Operations equal.: 3045.1200 SM: 3045.1200
# [+]Comparing RTE: 3045.1300 SM: 3045.1300
# 	[+]Operations equal.: 3045.1300 SM: 3045.1300
# [+]Comparing RTE: 3050.1400 SM: 3050.1400
# 	[+]Operations equal.: 3050.1400 SM: 3050.1400
# [+]Comparing RTE: 3050.1401 SM: 3050.1401
# 	[+]Operations equal.: 3050.1401 SM: 3050.1401
# [+]Comparing RTE: 3050.1500 SM: 3050.1500
# 	[+]Operations equal.: 3050.1500 SM: 3050.1500
# [+]Comparing RTE: 3050.1501 SM: 3050.1501
# 	[+]Operations equal.: 3050.1501 SM: 3050.1501
# [+]Comparing RTE: 3050.3000 SM: 3050.3000
# 	[+]Operations equal.: 3050.3000 SM: 3050.3000
# [+]Comparing RTE: 3065.1000 SM: 3065.1000
# 	[+]Operations equal.: 3065.1000 SM: 3065.1000
# [+]Comparing RTE: 3070.1000 SM: 3070.1000
# 	[+]Operations equal.: 3070.1000 SM: 3070.1000
# [+]Comparing RTE: 3070.2000 SM: 3070.2000
# 	[+]Operations equal.: 3070.2000 SM: 3070.2000
# [+]Comparing RTE: 3070.2100 SM: 3070.2100
# 	[+]Operations equal.: 3070.2100 SM: 3070.2100
# [+]Comparing RTE: 3070.2200 SM: 3070.2200
# 	[+]Operations equal.: 3070.2200 SM: 3070.2200
# [+]Comparing RTE: 3070.3000 SM: 3070.3000
# 	[+]Operations equal.: 3070.3000 SM: 3070.3000
# [+]Comparing RTE: 3075.1000 SM: 3075.1000
# 	[+]Operations equal.: 3075.1000 SM: 3075.1000
# [+]Comparing RTE: 3075.1200 SM: 3075.1200
# 	[+]Operations equal.: 3075.1200 SM: 3075.1200
# [+]Comparing RTE: 3075.2000 SM: 3075.2000
# 	[+]Operations equal.: 3075.2000 SM: 3075.2000
# [+]Comparing RTE: 3080.1000 SM: 3080.1000
# 	[+]Operations equal.: 3080.1000 SM: 3080.1000
# [+]Comparing RTE: 3080.2000 SM: 3080.2000
# 	[+]Operations equal.: 3080.2000 SM: 3080.2000
# [+]Comparing RTE: 3085.1000 SM: 3085.1000
# 	[+]Operations equal.: 3085.1000 SM: 3085.1000
# [+]Comparing RTE: 3085.1100 SM: 3085.1100
# 	[+]Operations equal.: 3085.1100 SM: 3085.1100
# [+]Comparing RTE: 3085.2000 SM: 3085.2000
# 	[+]Operations equal.: 3085.2000 SM: 3085.2000
# [+]Comparing RTE: 3090.1000 SM: 3090.1000
# 	[+]Operations equal.: 3090.1000 SM: 3090.1000
# [+]Comparing RTE: 3090.2000 SM: 3090.2000
# 	[+]Operations equal.: 3090.2000 SM: 3090.2000
# [+]Comparing RTE: 3095.1000 SM: 3095.1000
# 	[+]Operations equal.: 3095.1000 SM: 3095.1000
# [+]Comparing RTE: 3100.1000 SM: 3100.1000
# 	[+]Operations equal.: 3100.1000 SM: 3100.1000
# [+]Comparing RTE: 3100.1100 SM: 3100.1100
# 	[+]Operations equal.: 3100.1100 SM: 3100.1100
# [+]Comparing RTE: 3100.1200 SM: 3100.1200
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 3100.1300 SM: 3100.1300
# 	[+]Operations equal.: 3100.1300 SM: 3100.1300
# [+]Comparing RTE: 3105.1000 SM: 3105.1000
# 	[+]Operations equal.: 3105.1000 SM: 3105.1000
# [+]Comparing RTE: 3105.2000 SM: 3105.2000
# 	[+]Operations equal.: 3105.2000 SM: 3105.2000
# [+]Comparing RTE: 3105.3000 SM: 3105.3000
# 	[+]Operations equal.: 3105.3000 SM: 3105.3000
# [+]Comparing RTE: 3105.3500 SM: 3105.3500
# 	[+]Operations equal.: 3105.3500 SM: 3105.3500
# [+]Comparing RTE: 3110.1000 SM: 3110.1000
# 	[+]Operations equal.: 3110.1000 SM: 3110.1000
# [+]Comparing RTE: 3115.1000 SM: 3115.1000
# 	[+]Operations equal.: 3115.1000 SM: 3115.1000
# [+]Comparing RTE: 3115.4000 SM: 3115.4000
# 	[+]Operations equal.: 3115.4000 SM: 3115.4000
# [+]Comparing RTE: 3115.5000 SM: 3115.5000
# 	[+]Operations equal.: 3115.5000 SM: 3115.5000
# [+]Comparing RTE: 3120.1000 SM: 3120.1000
# 	[+]Operations equal.: 3120.1000 SM: 3120.1000
# [+]Comparing RTE: 3120.2000 SM: 3120.2000
# 	[+]Operations equal.: 3120.2000 SM: 3120.2000
# [+]Comparing RTE: 3125.1000 SM: 3125.1000
# 	[+]Operations equal.: 3125.1000 SM: 3125.1000
# [+]Comparing RTE: 3130.5000 SM: 3130.5000
# 	[+]Operations equal.: 3130.5000 SM: 3130.5000
# [+]Comparing RTE: 3130.5100 SM: 3130.5100
# 	[+]Operations equal.: 3130.5100 SM: 3130.5100
# [+]Comparing RTE: 3130.6000 SM: 3130.6000
# 	[+]Operations equal.: 3130.6000 SM: 3130.6000
# [+]Comparing RTE: 3130.6100 SM: 3130.6100
# 	[+]Operations equal.: 3130.6100 SM: 3130.6100
# [+]Comparing RTE: 3130.6200 SM: 3130.6200
# 	[+]Operations equal.: 3130.6200 SM: 3130.6200
# [+]Comparing RTE: 3130.7000 SM: 3130.7000
# 	[+]Operations equal.: 3130.7000 SM: 3130.7000
# [+]Comparing RTE: 3130.7100 SM: 3130.7100
# 	[+]Operations equal.: 3130.7100 SM: 3130.7100
# [+]Comparing RTE: 3135.8000 SM: 3135.8000
# 	[+]Operations equal.: 3135.8000 SM: 3135.8000
# [+]Comparing RTE: 3135.8100 SM: 3135.8100
# 	[+]Operations equal.: 3135.8100 SM: 3135.8100
# [+]Comparing RTE: 3135.8200 SM: 3135.8200
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 3135.8300 SM: 3135.8300
# 	[+]Operations equal.: 3135.8300 SM: 3135.8300
# [+]Comparing RTE: 3140.1000 SM: 3140.1000
# 	[+]Operations equal.: 3140.1000 SM: 3140.1000
# [+]Comparing RTE: 3140.2000 SM: 3140.2000
# 	[+]Operations equal.: 3140.2000 SM: 3140.2000
# [+]Comparing RTE: 3140.3000 SM: 3140.3000
# 	[+]Operations equal.: 3140.3000 SM: 3140.3000
# [+]Comparing RTE: 3140.3500 SM: 3140.3500
# 	[+]Operations equal.: 3140.3500 SM: 3140.3500
# [+]Comparing RTE: 3145.1000 SM: 3145.1000
# 	[+]Operations equal.: 3145.1000 SM: 3145.1000
# [+]Comparing RTE: 3145.2000 SM: 3145.2000
# 	[+]Operations equal.: 3145.2000 SM: 3145.2000
# [+]Comparing RTE: 3145.2020 SM: 3145.2020
# 	[+]Operations equal.: 3145.2020 SM: 3145.2020
# [+]Comparing RTE: 3145.2200 SM: 3145.2200
# 	[+]Operations equal.: 3145.2200 SM: 3145.2200
# [+]Comparing RTE: 3145.2250 SM: 3145.2250
# 	[+]Operations equal.: 3145.2250 SM: 3145.2250
# [+]Comparing RTE: 3145.2260 SM: 3145.2260
# 	[+]Operations equal.: 3145.2260 SM: 3145.2260
# [+]Comparing RTE: 3145.2300 SM: 3145.2300
# 	[+]Operations equal.: 3145.2300 SM: 3145.2300
# [+]Comparing RTE: 3145.2400 SM: 3145.2400
# 	[+]Operations equal.: 3145.2400 SM: 3145.2400
# [+]Comparing RTE: 3150.2500 SM: 3150.2500
# 	[+]Operations equal.: 3150.2500 SM: 3150.2500
# [+]Comparing RTE: 3150.3000 SM: 3150.3000
# 	[+]Operations equal.: 3150.3000 SM: 3150.3000
# [+]Comparing RTE: 3150.3100 SM: 3150.3100
# 	[+]Operations equal.: 3150.3100 SM: 3150.3100
# [+]Comparing RTE: 3150.3200 SM: 3150.3200
# 	[+]Operations equal.: 3150.3200 SM: 3150.3200
# [+]Comparing RTE: 3155.4000 SM: 3155.4000
# 	[+]Operations equal.: 3155.4000 SM: 3155.4000
# [+]Comparing RTE: 3155.4100 SM: 3155.4100
# 	[+]Operations equal.: 3155.4100 SM: 3155.4100
# [+]Comparing RTE: 3155.5000 SM: 3155.5000
# 	[+]Operations equal.: 3155.5000 SM: 3155.5000
# [+]Comparing RTE: 3155.6000 SM: 3155.6000
# 	[+]Operations equal.: 3155.6000 SM: 3155.6000
# [+]Comparing RTE: 3155.7000 SM: 3155.7000
# 	[+]Operations equal.: 3155.7000 SM: 3155.7000
# [+]Comparing RTE: 3160.1000 SM: 3160.1000
# 	[+]Operations equal.: 3160.1000 SM: 3160.1000
# [+]Comparing RTE: 3160.1020 SM: 3160.1020
# 	[+]Operations equal.: 3160.1020 SM: 3160.1020
# [+]Comparing RTE: 3160.1100 SM: 3160.1100
# 	[+]Operations equal.: 3160.1100 SM: 3160.1100
# [+]Comparing RTE: 3160.1110 SM: 3160.1110
# 	[+]Operations equal.: 3160.1110 SM: 3160.1110
# [+]Comparing RTE: 3160.1120 SM: 3160.1120
# 	[+]Operations equal.: 3160.1120 SM: 3160.1120
# [+]Comparing RTE: 3160.1200 SM: 3160.1200
# 	[+]Operations equal.: 3160.1200 SM: 3160.1200
# [+]Comparing RTE: 3160.1300 SM: 3160.1300
# 	[+]Operations equal.: 3160.1300 SM: 3160.1300
# [+]Comparing RTE: 3165.1400 SM: 3165.1400
# 	[+]Operations equal.: 3165.1400 SM: 3165.1400
# [+]Comparing RTE: 3165.2000 SM: 3165.2000
# 	[+]Operations equal.: 3165.2000 SM: 3165.2000
# [+]Comparing RTE: 3165.3000 SM: 3165.3000
# 	[+]Operations equal.: 3165.3000 SM: 3165.3000
# [+]Comparing RTE: 3180.1000 SM: 3180.1000
# 	[+]Operations equal.: 3180.1000 SM: 3180.1000
# [+]Comparing RTE: 3185.0750 SM: 3185.0750
# 	[+]Operations equal.: 3185.0750 SM: 3185.0750
# [+]Comparing RTE: 3185.0800 SM: 3185.0800
# 	[+]Operations equal.: 3185.0800 SM: 3185.0800
# [+]Comparing RTE: 3185.0810 SM: 3185.0810
# 	[+]Operations equal.: 3185.0810 SM: 3185.0810
# [+]Comparing RTE: 3185.0820 SM: 3185.0820
# 	[+]Operations equal.: 3185.0820 SM: 3185.0820
# [+]Comparing RTE: 3185.0850 SM: 3185.0850
# 	[+]Operations equal.: 3185.0850 SM: 3185.0850
# [+]Comparing RTE: 3185.0900 SM: 3185.0900
# 	[+]Operations equal.: 3185.0900 SM: 3185.0900
# [+]Comparing RTE: 3185.0950 SM: 3185.0950
# 	[+]Operations equal.: 3185.0950 SM: 3185.0950
# [+]Comparing RTE: 3190.0200 SM: 3190.0200
# 	[+]Operations equal.: 3190.0200 SM: 3190.0200
# [+]Comparing RTE: 3190.0300 SM: 3190.0300
# 	[+]Operations equal.: 3190.0300 SM: 3190.0300
# [+]Comparing RTE: 3190.0400 SM: 3190.0400
# 	[+]Operations equal.: 3190.0400 SM: 3190.0400
# [+]Comparing RTE: 3190.0405 SM: 3190.0405
# 	[+]Operations equal.: 3190.0405 SM: 3190.0405
# [+]Comparing RTE: 3190.0500 SM: 3190.0500
# 	[+]Operations equal.: 3190.0500 SM: 3190.0500
# [+]Comparing RTE: 3195.0600 SM: 3195.0600
# 	[+]Operations equal.: 3195.0600 SM: 3195.0600
# [+]Comparing RTE: 3195.0700 SM: 3195.0700
# 	[+]Operations equal.: 3195.0700 SM: 3195.0700
# [+]Comparing RTE: 3195.0800 SM: 3195.0800
# 	[+]Operations equal.: 3195.0800 SM: 3195.0800
# [+]Comparing RTE: 3195.0900 SM: 3195.0900
# 	[+]Operations equal.: 3195.0900 SM: 3195.0900
# [+]Comparing RTE: 3195.1000 SM: 3195.1000
# 	[+]Operations equal.: 3195.1000 SM: 3195.1000
# [+]Comparing RTE: 3195.1005 SM: 3195.1005
# 	[+]Operations equal.: 3195.1005 SM: 3195.1005
# [+]Comparing RTE: 3195.2000 SM: 3195.2000
# 	[+]Operations equal.: 3195.2000 SM: 3195.2000
# [+]Comparing RTE: 3200.1000 SM: 3200.1000
# 	[+]Operations equal.: 3200.1000 SM: 3200.1000
# [+]Comparing RTE: 3200.2000 SM: 3200.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 3200.3000 SM: 3200.3000
# 	[+]Operations equal.: 3200.3000 SM: 3200.3000
# [+]Comparing RTE: 3200.4000 SM: 3200.4000
# 	[+]Operations equal.: 3200.4000 SM: 3200.4000
# [+]Comparing RTE: 3200.5000 SM: 3200.5000
# 	[+]Operations equal.: 3200.5000 SM: 3200.5000
# [+]Comparing RTE: 3200.5005 SM: 3200.5005
# 	[+]Operations equal.: 3200.5005 SM: 3200.5005
# [+]Comparing RTE: 3200.6000 SM: 3200.6000
# 	[+]Operations equal.: 3200.6000 SM: 3200.6000
# [+]Comparing RTE: 3200.6005 SM: 3200.6005
# 	[+]Operations equal.: 3200.6005 SM: 3200.6005
# [+]Comparing RTE: 3205.0500 SM: 3205.0500
# 	[+]Operations equal.: 3205.0500 SM: 3205.0500
# [+]Comparing RTE: 3205.0600 SM: 3205.0600
# 	[+]Operations equal.: 3205.0600 SM: 3205.0600
# [+]Comparing RTE: 3205.0700 SM: 3205.0700
# 	[+]Operations equal.: 3205.0700 SM: 3205.0700
# [+]Comparing RTE: 4200.0100 SM: 4200.0100
# 	[+]Operations equal.: 4200.0100 SM: 4200.0100
# [+]Comparing RTE: 4200.0200 SM: 4200.0200
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4200.0300 SM: 4200.0300
# 	[+]Operations equal.: 4200.0300 SM: 4200.0300
# [+]Comparing RTE: 4200.0400 SM: 4200.0400
# 	[+]Operations equal.: 4200.0400 SM: 4200.0400
# [+]Comparing RTE: 4200.0500 SM: 4200.0500
# 	[+]Operations equal.: 4200.0500 SM: 4200.0500
# [+]Comparing RTE: 4200.0501 SM: 4200.0501
# 	[+]Operations equal.: 4200.0501 SM: 4200.0501
# [+]Comparing RTE: 4205.0600 SM: 4205.0600
# 	[+]Operations equal.: 4205.0600 SM: 4205.0600
# [+]Comparing RTE: 4205.0700 SM: 4205.0700
# 	[+]Operations equal.: 4205.0700 SM: 4205.0700
# [+]Comparing RTE: 4205.0800 SM: 4205.0800
# 	[+]Operations equal.: 4205.0800 SM: 4205.0800
# [+]Comparing RTE: 4205.1000 SM: 4205.1000
# 	[+]Operations equal.: 4205.1000 SM: 4205.1000
# [+]Comparing RTE: 4205.1050 SM: 4205.1050
# 	[+]Operations equal.: 4205.1050 SM: 4205.1050
# [+]Comparing RTE: 4205.1100 SM: 4205.1100
# 	[+]Operations equal.: 4205.1100 SM: 4205.1100
# [+]Comparing RTE: 4205.1101 SM: 4205.1101
# 	[+]Operations equal.: 4205.1101 SM: 4205.1101
# [+]Comparing RTE: 4210.1100 SM: 4210.1100
# 	[+]Operations equal.: 4210.1100 SM: 4210.1100
# [+]Comparing RTE: 4215.1400 SM: 4215.1400
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4215.1500 SM: 4215.1500
# 	[+]Operations equal.: 4215.1500 SM: 4215.1500
# [+]Comparing RTE: 4215.1600 SM: 4215.1600
# 	[+]Operations equal.: 4215.1600 SM: 4215.1600
# [+]Comparing RTE: 4220.1700 SM: 4220.1700
# 	[+]Operations equal.: 4220.1700 SM: 4220.1700
# [+]Comparing RTE: 4220.1800 SM: 4220.1800
# 	[+]Operations equal.: 4220.1800 SM: 4220.1800
# [+]Comparing RTE: 4230.2400 SM: 4230.2400
# 	[+]Operations equal.: 4230.2400 SM: 4230.2400
# [+]Comparing RTE: 4230.2401 SM: 4230.2401
# 	[+]Operations equal.: 4230.2401 SM: 4230.2401
# [+]Comparing RTE: 4230.2500 SM: 4230.2500
# 	[+]Operations equal.: 4230.2500 SM: 4230.2500
# [+]Comparing RTE: 4230.2501 SM: 4230.2501
# 	[+]Operations equal.: 4230.2501 SM: 4230.2501
# [+]Comparing RTE: 4231.0750 SM: 4231.0750
# 	[+]Operations equal.: 4231.0750 SM: 4231.0750
# [+]Comparing RTE: 4231.0800 SM: 4231.0800
# 	[+]Operations equal.: 4231.0800 SM: 4231.0800
# [+]Comparing RTE: 4231.0850 SM: 4231.0850
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4231.0900 SM: 4231.0900
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4231.0950 SM: 4231.0950
# 	[+]Operations equal.: 4231.0950 SM: 4231.0950
# [+]Comparing RTE: 4232.0200 SM: 4232.0200
# 	[+]Operations equal.: 4232.0200 SM: 4232.0200
# [+]Comparing RTE: 4232.0300 SM: 4232.0300
# 	[+]Operations equal.: 4232.0300 SM: 4232.0300
# [+]Comparing RTE: 4232.0400 SM: 4232.0400
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4232.0405 SM: 4232.0405
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4232.0500 SM: 4232.0500
# 	[+]Operations equal.: 4232.0500 SM: 4232.0500
# [+]Comparing RTE: 4233.1000 SM: 4233.1000
# 	[+]Operations equal.: 4233.1000 SM: 4233.1000
# [+]Comparing RTE: 4233.2000 SM: 4233.2000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4233.3000 SM: 4233.3000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4234.1000 SM: 4234.1000
# 	[+]Operations equal.: 4234.1000 SM: 4234.1000
# [+]Comparing RTE: 4234.2000 SM: 4234.2000
# 	[+]Operations equal.: 4234.2000 SM: 4234.2000
# [+]Comparing RTE: 4234.2500 SM: 4234.2500
# 	[+]Operations equal.: 4234.2500 SM: 4234.2500
# [+]Comparing RTE: 4234.2501 SM: 4234.2501
# 	[+]Operations equal.: 4234.2501 SM: 4234.2501
# [+]Comparing RTE: 4235.1000 SM: 4235.1000
# 	[+]Operations equal.: 4235.1000 SM: 4235.1000
# [+]Comparing RTE: 4235.1500 SM: 4235.1500
# 	[+]Operations equal.: 4235.1500 SM: 4235.1500
# [+]Comparing RTE: 4235.1501 SM: 4235.1501
# 	[+]Operations equal.: 4235.1501 SM: 4235.1501
# [+]Comparing RTE: 4235.2000 SM: 4235.2000
# ...
# 	[+]Operations equal.: 4240.1000 SM: 4240.1000
# [+]Comparing RTE: 4240.1300 SM: 4240.1300
# 	[+]Operations equal.: 4240.1300 SM: 4240.1300
# [+]Comparing RTE: 4240.1500 SM: 4240.1500
# 	[+]Operations equal.: 4240.1500 SM: 4240.1500
# [+]Comparing RTE: 4240.1501 SM: 4240.1501
# 	[+]Operations equal.: 4240.1501 SM: 4240.1501
# [+]Comparing RTE: 4240.2000 SM: 4240.2000
# 	[+]Operations equal.: 4240.2000 SM: 4240.2000
# [+]Comparing RTE: 4241.1000 SM: 4241.1000
# 	[+]Operations equal.: 4241.1000 SM: 4241.1000
# [+]Comparing RTE: 4241.2000 SM: 4241.2000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4241.2500 SM: 4241.2500
# 	[+]Operations equal.: 4241.2500 SM: 4241.2500
# [+]Comparing RTE: 4241.2501 SM: 4241.2501
# 	[+]Operations equal.: 4241.2501 SM: 4241.2501
# [+]Comparing RTE: 4241.3000 SM: 4241.3000
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4241.4000 SM: 4241.4000
# 	[+]Operations equal.: 4241.4000 SM: 4241.4000
# [+]Comparing RTE: 4242.1000 SM: 4242.1000
# 	[+]Operations equal.: 4242.1000 SM: 4242.1000
# [+]Comparing RTE: 4242.2000 SM: 4242.2000
# 	[+]Operations equal.: 4242.2000 SM: 4242.2000
# [+]Comparing RTE: 4242.3000 SM: 4242.3000
# 	[+]Operations equal.: 4242.3000 SM: 4242.3000
# [+]Comparing RTE: 4242.4000 SM: 4242.4000
# 	[+]Operations equal.: 4242.4000 SM: 4242.4000
# [+]Comparing RTE: 4242.4200 SM: 4242.4200
# 	[+]Operations equal.: 4242.4200 SM: 4242.4200
# [+]Comparing RTE: 4242.4300 SM: 4242.4300
# 	[+]Operations equal.: 4242.4300 SM: 4242.4300
# [+]Comparing RTE: 4242.4400 SM: 4242.4400
# 	[+]Operations equal.: 4242.4400 SM: 4242.4400
# [+]Comparing RTE: 4242.4500 SM: 4242.4500
# 	[+]Operations equal.: 4242.4500 SM: 4242.4500
# [+]Comparing RTE: 4243.1000 SM: 4243.1000
# 	[+]Operations equal.: 4243.1000 SM: 4243.1000
# [+]Comparing RTE: 4243.3000 SM: 4243.3000
# 	[+]Operations equal.: 4243.3000 SM: 4243.3000
# [+]Comparing RTE: 4243.3100 SM: 4243.3100
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4243.3101 SM: 4243.3101
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4244.1000 SM: 4244.1000
# 	[+]Operations equal.: 4244.1000 SM: 4244.1000
# [+]Comparing RTE: 4244.3000 SM: 4244.3000
# 	[+]Operations equal.: 4244.3000 SM: 4244.3000
# [+]Comparing RTE: 4244.3100 SM: 4244.3100
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4244.3101 SM: 4244.3101
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4244.3200 SM: 4244.3200
# 	[+]Operations equal.: 4244.3200 SM: 4244.3200
# [+]Comparing RTE: 4244.3201 SM: 4244.3201
# 	[+]Operations equal.: 4244.3201 SM: 4244.3201
# [+]Comparing RTE: 4245.3300 SM: 4245.3300
# 	[+]Operations equal.: 4245.3300 SM: 4245.3300
# [+]Comparing RTE: 4245.3400 SM: 4245.3400
# 	[+]Operations equal.: 4245.3400 SM: 4245.3400
# [+]Comparing RTE: 4245.3500 SM: 4245.3500
# 	[+]Operations equal.: 4245.3500 SM: 4245.3500
# [+]Comparing RTE: 4245.3600 SM: 4245.3600
# 	[+]Operations equal.: 4245.3600 SM: 4245.3600
# [+]Comparing RTE: 4245.3700 SM: 4245.3700
# 	[+]Operations equal.: 4245.3700 SM: 4245.3700
# [+]Comparing RTE: 4245.3701 SM: 4245.3701
# 	[+]Operations equal.: 4245.3701 SM: 4245.3701
# [+]Comparing RTE: 4250.0000 SM: 4250.0000
# 	[+]Operations equal.: 4250.0000 SM: 4250.0000
# [+]Comparing RTE: 4250.0100 SM: 4250.0100
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4250.0200 SM: 4250.0200
# 	[+]Operations equal.: 4250.0200 SM: 4250.0200
# [+]Comparing RTE: 4250.0300 SM: 4250.0300
# 	[+]Operations equal.: 4250.0300 SM: 4250.0300
# [+]Comparing RTE: 4250.0400 SM: 4250.0400
# 	[+]Operations equal.: 4250.0400 SM: 4250.0400
# [+]Comparing RTE: 4250.0401 SM: 4250.0401
# 	[+]Operations equal.: 4250.0401 SM: 4250.0401
# [+]Comparing RTE: 4255.0500 SM: 4255.0500
# 	[+]Operations equal.: 4255.0500 SM: 4255.0500
# [+]Comparing RTE: 4255.0600 SM: 4255.0600
# 	[+]Operations equal.: 4255.0600 SM: 4255.0600
# [+]Comparing RTE: 4255.0700 SM: 4255.0700
# 	[+]Operations equal.: 4255.0700 SM: 4255.0700
# [+]Comparing RTE: 4255.0750 SM: 4255.0750
# 	[+]Operations equal.: 4255.0750 SM: 4255.0750
# [+]Comparing RTE: 4255.0751 SM: 4255.0751
# 	[+]Operations equal.: 4255.0751 SM: 4255.0751
# [+]Comparing RTE: 4262.0800 SM: 4262.0800
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4262.0900 SM: 4262.0900
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4262.1000 SM: 4262.1000
# 	[+]Operations equal.: 4262.1000 SM: 4262.1000
# [+]Comparing RTE: 4262.1100 SM: 4262.1100
# 	[+]Operations equal.: 4262.1100 SM: 4262.1100
# [+]Comparing RTE: 4262.1200 SM: 4262.1200
# 	[+]Operations equal.: 4262.1200 SM: 4262.1200
# [+]Comparing RTE: 4262.1201 SM: 4262.1201
# 	[+]Operations equal.: 4262.1201 SM: 4262.1201
# [+]Comparing RTE: 4267.1300 SM: 4267.1300
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4267.1400 SM: 4267.1400
# 	[+]Operations equal.: 4267.1400 SM: 4267.1400
# [+]Comparing RTE: 4267.1500 SM: 4267.1500
# 	[+]Operations equal.: 4267.1500 SM: 4267.1500
# [+]Comparing RTE: 4267.1700 SM: 4267.1700
# 	[+]Operations equal.: 4267.1700 SM: 4267.1700
# [+]Comparing RTE: 4267.1720 SM: 4267.1720
# 	[+]Operations equal.: 4267.1720 SM: 4267.1720
# [+]Comparing RTE: 4267.1750 SM: 4267.1750
# 	[+]Operations equal.: 4267.1750 SM: 4267.1750
# [+]Comparing RTE: 4267.1751 SM: 4267.1751
# 	[+]Operations equal.: 4267.1751 SM: 4267.1751
# [+]Comparing RTE: 4270.1800 SM: 4270.1800
# 	[+]Operations equal.: 4270.1800 SM: 4270.1800
# [+]Comparing RTE: 4273.2100 SM: 4273.2100
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4273.2200 SM: 4273.2200
# 	[+]Operations equal.: 4273.2200 SM: 4273.2200
# [+]Comparing RTE: 4273.2300 SM: 4273.2300
# 	[+]Operations equal.: 4273.2300 SM: 4273.2300
# [+]Comparing RTE: 4278.2400 SM: 4278.2400
# 	[+]Operations equal.: 4278.2400 SM: 4278.2400
# [+]Comparing RTE: 4278.2440 SM: 4278.2440
# 	[+]Operations equal.: 4278.2440 SM: 4278.2440
# [+]Comparing RTE: 4278.2500 SM: 4278.2500
# 	[+]Operations equal.: 4278.2500 SM: 4278.2500
# [+]Comparing RTE: 4280.2900 SM: 4280.2900
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4280.2910 SM: 4280.2910
# 	[+]Operations equal.: 4280.2910 SM: 4280.2910
# [+]Comparing RTE: 4280.2950 SM: 4280.2950
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 4280.2951 SM: 4280.2951
# 	[+]Operations equal.: 4280.2951 SM: 4280.2951
# [+]Comparing RTE: 4280.3000 SM: 4280.3000
# 	[+]Operations equal.: 4280.3000 SM: 4280.3000
# [+]Comparing RTE: 4283.3100 SM: 4283.3100
# 	[+]Operations equal.: 4283.3100 SM: 4283.3100
# [+]Comparing RTE: 4283.3101 SM: 4283.3101
# 	[+]Operations equal.: 4283.3101 SM: 4283.3101
# [+]Comparing RTE: 4283.3200 SM: 4283.3200
# 	[+]Operations equal.: 4283.3200 SM: 4283.3200
# [+]Comparing RTE: 4283.3201 SM: 4283.3201
# 	[+]Operations equal.: 4283.3201 SM: 4283.3201
# [+]Comparing RTE: 5710.3200 SM: 5710.3200
# 	[+]Operations equal.: 5710.3200 SM: 5710.3200
# [+]Comparing RTE: 5710.3300 SM: 5710.3300
# 	[+]Operations equal.: 5710.3300 SM: 5710.3300
# [+]Comparing RTE: 5710.3400 SM: 5710.3400
# 	[+]Operations equal.: 5710.3400 SM: 5710.3400
# [+]Comparing RTE: 5710.3401 SM: 5710.3401
# 	[+]Operations equal.: 5710.3401 SM: 5710.3401
# [+]Comparing RTE: 5715.3500 SM: 5715.3500
# 	[+]Operations equal.: 5715.3500 SM: 5715.3500
# [+]Comparing RTE: 5715.3600 SM: 5715.3600
# 	[+]Operations equal.: 5715.3600 SM: 5715.3600
# [+]Comparing RTE: 5715.3700 SM: 5715.3700
# 	[+]Operations equal.: 5715.3700 SM: 5715.3700
# [+]Comparing RTE: 5715.3701 SM: 5715.3701
# 	[+]Operations equal.: 5715.3701 SM: 5715.3701
# [+]Comparing RTE: 5720.3800 SM: 5720.3800
# 	[+]Operations equal.: 5720.3800 SM: 5720.3800
# [+]Comparing RTE: 5720.3900 SM: 5720.3900
# 	[+]Operations equal.: 5720.3900 SM: 5720.3900
# [+]Comparing RTE: 5720.4000 SM: 5720.4000
# 	[+]Operations equal.: 5720.4000 SM: 5720.4000
# [+]Comparing RTE: 5720.4001 SM: 5720.4001
# 	[+]Operations equal.: 5720.4001 SM: 5720.4001
# [+]Comparing RTE: 5720.4100 SM: 5720.4100
# 	[+]Operations equal.: 5720.4100 SM: 5720.4100
# [+]Comparing RTE: 5735.0000 SM: 5735.0000
# 	[+]Operations equal.: 5735.0000 SM: 5735.0000
# [+]Comparing RTE: 5735.0500 SM: 5735.0500
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 5735.1002 SM: 5735.1002
# 	[+]Operations equal.: 5735.1002 SM: 5735.1002
# [+]Comparing RTE: 5735.2000 SM: 5735.2000
# 	[X]Operation difference due to value.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 5735.2050 SM: 5735.2050
# 	[+]Operations equal.: 5735.2050 SM: 5735.2050
# [+]Comparing RTE: 5735.2051 SM: 5735.2051
# 	[+]Operations equal.: 5735.2051 SM: 5735.2051
# [+]Comparing RTE: 5755.2500 SM: 5755.2500
# 	[+]Operations equal.: 5755.2500 SM: 5755.2500
# [+]Comparing RTE: 5755.2600 SM: 5755.2600
# 	[+]Operations equal.: 5755.2600 SM: 5755.2600
# [+]Comparing RTE: 5755.2700 SM: 5755.2700
# 	[+]Operations equal.: 5755.2700 SM: 5755.2700
# [+]Comparing RTE: 5755.3002 SM: 5755.3002
# 	[+]Operations equal.: 5755.3002 SM: 5755.3002
# [+]Comparing RTE: 5755.3050 SM: 5755.3050
# 	[+]Operations equal.: 5755.3050 SM: 5755.3050
# [+]Comparing RTE: 5755.3051 SM: 5755.3051
# 	[+]Operations equal.: 5755.3051 SM: 5755.3051
# [+]Comparing RTE: 5755.3100 SM: 5755.3100
# 	[+]Operations equal.: 5755.3100 SM: 5755.3100
# [+]Comparing RTE: 5755.3101 SM: 5755.3101
# 	[+]Operations equal.: 5755.3101 SM: 5755.3101
# [+]Comparing RTE: 5760.4000 SM: 5760.4000
# 	[+]Operations equal.: 5760.4000 SM: 5760.4000
# [+]Comparing RTE: 5760.4030 SM: 5760.4030
# 	[+]Operations equal.: 5760.4030 SM: 5760.4030
# [+]Comparing RTE: 5760.4031 SM: 5760.4031
# 	[+]Operations equal.: 5760.4031 SM: 5760.4031
# [+]Comparing RTE: 5760.4100 SM: 5760.4100
# 	[+]Operations equal.: 5760.4100 SM: 5760.4100
# [+]Comparing RTE: 5795.0000 SM: 5795.0000
# 	[+]Operations equal.: 5795.0000 SM: 5795.0000
# [+]Comparing RTE: 5795.0500 SM: 5795.0500
# 	[X]Operation difference due to length.
# 	[+]Operation difference neutralized by MM sheet.:
# [+]Comparing RTE: 5795.1002 SM: 5795.1002
# 	[+]Operations equal.: 5795.1002 SM: 5795.1002
# [+]Comparing RTE: 5795.2000 SM: 5795.2000
# 	[+]Operations equal.: 5795.2000 SM: 5795.2000
# [+]Comparing RTE: 5795.2050 SM: 5795.2050
# 	[+]Operations equal.: 5795.2050 SM: 5795.2050
# [+]Comparing RTE: 5795.2051 SM: 5795.2051
# 	[+]Operations equal.: 5795.2051 SM: 5795.2051
# [+]Comparing RTE: 5815.2500 SM: 5815.2500
# 	[+]Operations equal.: 5815.2500 SM: 5815.2500
# [+]Comparing RTE: 5815.2700 SM: 5815.2700
# 	[+]Operations equal.: 5815.2700 SM: 5815.2700
# [+]Comparing RTE: 5815.2750 SM: 5815.2750
# 	[+]Operations equal.: 5815.2750 SM: 5815.2750
# [+]Comparing RTE: 5815.2800 SM: 5815.2800
# 	[+]Operations equal.: 5815.2800 SM: 5815.2800
# [+]Comparing RTE: 5815.3002 SM: 5815.3002
# 	[+]Operations equal.: 5815.3002 SM: 5815.3002
# [+]Comparing RTE: 5815.4000 SM: 5815.4000
# 	[+]Operations equal.: 5815.4000 SM: 5815.4000
# [+]Comparing RTE: 5815.4050 SM: 5815.4050
# 	[+]Operations equal.: 5815.4050 SM: 5815.4050
# [+]Comparing RTE: 5815.4051 SM: 5815.4051
# 	[+]Operations equal.: 5815.4051 SM: 5815.4051
# [+]Comparing RTE: 6835.4000 SM: 6835.4000
# 	[+]Operations equal.: 6835.4000 SM: 6835.4000
# [+]Comparing RTE: 6835.4500 SM: 6835.4500
# 	[+]Operations equal.: 6835.4500 SM: 6835.4500
# [+]Comparing RTE: 6835.4600 SM: 6835.4600
# 	[+]Operations equal.: 6835.4600 SM: 6835.4600
# [+]Comparing RTE: 6835.4601 SM: 6835.4601
# 	[+]Operations equal.: 6835.4601 SM: 6835.4601
# [+]Comparing RTE: 6840.4700 SM: 6840.4700
# 	[+]Operations equal.: 6840.4700 SM: 6840.4700
# [+]Comparing RTE: 6840.5000 SM: 6840.5000
# 	[+]Operations equal.: 6840.5000 SM: 6840.5000
# [+]Comparing RTE: 6845.5000 SM: 6845.5000
# 	[+]Operations equal.: 6845.5000 SM: 6845.5000
# [+]Comparing RTE: 6845.5500 SM: 6845.5500
# 	[+]Operations equal.: 6845.5500 SM: 6845.5500
# [+]Comparing RTE: 6845.5600 SM: 6845.5600
# 	[+]Operations equal.: 6845.5600 SM: 6845.5600
# [+]Comparing RTE: 6845.5601 SM: 6845.5601
# 	[+]Operations equal.: 6845.5601 SM: 6845.5601
# [+]Comparing RTE: 6850.1000 SM: 6850.1000
# 	[+]Operations equal.: 6850.1000 SM: 6850.1000
# [+]Comparing RTE: 6855.0000 SM: 6855.0000
# 	[+]Operations equal.: 6855.0000 SM: 6855.0000
# [+]Comparing RTE: 6855.1000 SM: 6855.1000
# 	[+]Operations equal.: 6855.1000 SM: 6855.1000
# [+]Comparing RTE: 6855.2000 SM: 6855.2000
# 	[+]Operations equal.: 6855.2000 SM: 6855.2000
# [+]Comparing RTE: 6855.3000 SM: 6855.3000
# 	[+]Operations equal.: 6855.3000 SM: 6855.3000
# [+]Comparing RTE: 6855.4000 SM: 6855.4000
# 	[+]Operations equal.: 6855.4000 SM: 6855.4000
# [+]Comparing RTE: 6875.5000 SM: 6875.5000
# 	[+]Operations equal.: 6875.5000 SM: 6875.5000
# [+]Comparing RTE: 6875.6000 SM: 6875.6000
# 	[+]Operations equal.: 6875.6000 SM: 6875.6000
# [+]Comparing RTE: 6875.6010 SM: 6875.6010
# 	[+]Operations equal.: 6875.6010 SM: 6875.6010
# [+]Comparing RTE: 6885.6400 SM: 6885.6400
# 	[+]Operations equal.: 6885.6400 SM: 6885.6400
# [+]Comparing RTE: 6885.6450 SM: 6885.6450
# 	[+]Operations equal.: 6885.6450 SM: 6885.6450
# [+]Comparing RTE: 6885.6500 SM: 6885.6500
# 	[+]Operations equal.: 6885.6500 SM: 6885.6500
# [+]Comparing RTE: 6885.6510 SM: 6885.6510
# 	[+]Operations equal.: 6885.6510 SM: 6885.6510
# [+]Comparing RTE: 6885.6600 SM: 6885.6600
# 	[X]Operation difference due to value.
# 	[+]Writing operation difference.
# [+]Comparing RTE: 6885.6601 SM: 6885.6601
# 	[+]Operations equal.: 6885.6601 SM: 6885.6601
# [+]Comparing RTE: 6885.6700 SM: 6885.6700
# 	[X]Operation difference due to value.
# 	[+]Writing operation difference.
# [+]Comparing RTE: 6885.6710 SM: 6885.6710
# 	[+]Operations equal.: 6885.6710 SM: 6885.6710
# [+]Comparing RTE: 6885.7700 SM: 6885.7700
# 	[X]Operation difference due to value.
# 	[+]Writing operation difference.
# [+]Comparing RTE: 6885.7701 SM: 6885.7701
# 	[+]Operations equal.: 6885.7701 SM: 6885.7701
# [+]Comparing RTE: 6885.7705 SM: 6885.7705
# 	[+]Operations equal.: 6885.7705 SM: 6885.7705
# [+]Comparing RTE: 6885.7710 SM: 6885.7710
# 	[+]Operations equal.: 6885.7710 SM: 6885.7710
# [+]Comparing RTE: 6885.7715 SM: 6885.7715
# 	[+]Operations equal.: 6885.7715 SM: 6885.7715
# [+]Comparing RTE: 6885.7720 SM: 6885.7720
# 	[+]Operations equal.: 6885.7720 SM: 6885.7720
# [+]Comparing RTE: 6885.7725 SM: 6885.7725
# 	[+]Operations equal.: 6885.7725 SM: 6885.7725
# [+]Comparing RTE: 6885.7730 SM: 6885.7730
# 	[+]Operations equal.: 6885.7730 SM: 6885.7730
# [+]Comparing RTE: 9800.1000 SM: 9800.1000
# 	[+]Operations equal.: 9800.1000 SM: 9800.1000
# [+]Comparing RTE: 9800.1100 SM: 9800.1100
# 	[+]Operations equal.: 9800.1100 SM: 9800.1100
# [+]Comparing RTE: 9850.1000 SM: 9850.1000
# 	[+]Operations equal.: 9850.1000 SM: 9850.1000
# [+]Comparing RTE: 9905.0000 SM: 9905.0000
# 	[+]Operations equal.: 9905.0000 SM: 9905.0000
# [+]Comparing RTE: 9905.0025 SM: 9905.0025
# 	[+]Operations equal.: 9905.0025 SM: 9905.0025
# [+]Comparing RTE: 9905.0050 SM: 9905.0050
# 	[+]Operations equal.: 9905.0050 SM: 9905.0050
# [+]Comparing RTE: 9905.0200 SM: 9905.0200
# 	[+]Operations equal.: 9905.0200 SM: 9905.0200
# [+]Comparing RTE: 9905.0400 SM: 9905.0400
# 	[+]Operations equal.: 9905.0400 SM: 9905.0400
# [+]Comparing RTE: 9905.0500 SM: 9905.0500
# 	[+]Operations equal.: 9905.0500 SM: 9905.0500
# [+]Comparing RTE: 9915.1000 SM: 9915.1000
# 	[+]Operations equal.: 9915.1000 SM: 9915.1000
# [+]Comparing RTE: 9925.0251 SM: 9925.0251
# 	[+]Operations equal.: 9925.0251 SM: 9925.0251
# [+]Comparing RTE: 9925.0501 SM: 9925.0501
# 	[+]Operations equal.: 9925.0501 SM: 9925.0501
# [+]Comparing RTE: 9925.0751 SM: 9925.0751
# 	[+]Operations equal.: 9925.0751 SM: 9925.0751
# [+]Comparing RTE: 9950.1000 SM: 9950.1000
# 	[+]Operations equal.: 9950.1000 SM: 9950.1000
# [+]Comparing RTE: 9999.9998 SM: 9999.9998
# 	[+]Operations equal.: 9999.9998 SM: 9999.9998
# [+]Comparing RTE: 9999.9999 SM: 9999.9999
# 	[+]Operations equal.: 9999.9999 SM: 9999.9999
# Complete.

# %%
#pass in cell, return .value as string with no leading/trailing whitespace
def stringify(cell):
    return str(cell.value).strip()

# %%
'''
returns True if the openpyxl cell has a value, False otherwise
'''
def has_value(cell):
    return cell.value != '' and cell.value != None

# %%
'''
given a report_id, extract the route ID
'''
def get_route_id(report_id):
    try:
        '''
        Expected report_ids:
        Flow Report (SM Version): [ROUTE_ID], [PRODUCT_ID]
        Flow Report (Production MM): [ROUTE_ID], [PRODUCT_ID]
        '''
        return report_id.split(':')[1].strip().split(',')[0]
    except:
        return 'ErrorReadingRouteID'

# %%
'''
given a report_id, extract the product ID
'''
def get_product_id(report_id):
    try:
        '''
        Expected report_ids:
        Flow Report (SM Version): [ROUTE_ID], [PRODUCT_ID]
        Flow Report (Production MM): [ROUTE_ID], [PRODUCT_ID]
        '''
        return report_id.split(':')[1].strip().split(',')[1].strip()
    except:
        return 'ErrorReadingProduct'

# %%
'''
saves output_worksheet to the generated path & filename
'''
def save_output():
    file_name = generate_filename(rte_route)
    output_workbook.save(file_name)
    format_output(file_name)

# %%
'''
initializes the WriteOnlyWorkbook that is used for output
creates approproate sheets for output and user post processing verification
'''
from openpyxl import Workbook
def init_write_only_output():
    workbook = Workbook(write_only=True)
    workbook.create_sheet(OUTPUT_TAB)
    workbook.create_sheet('RSR')
    workbook.create_sheet('PD-LR Verification')
    
    for i in range(HEADER_BUFFER):
        workbook[OUTPUT_TAB].append([''])
    
    return workbook

# %%
'''
given a route, create a filename. 
    [SAVE_ROOT_PATH]/
        [ROUTE_ID]_RTE-SM-Compare_[YEAR-MONTH-DATE] [HOUR-MINUTE-SECOND]_[WINDOWS_ID]
creates user directory if not already existing
@param route: route to create filename for
'''
import os
import datetime as dt
def generate_filename(route):
    uid = os.getlogin()
    save_path = SAVE_ROOT_PATH + uid
    timestamp = str(dt.datetime.now())[:-7].replace(":", "-")
    file_name = save_path + '/' + route.get_route_id() + '_RTE-SM-Compare_' + timestamp + '_' + uid + '.xlsx'
    
    if not os.path.exists(save_path):
        os.mkdir(save_path)
        
    return file_name

# %%
'''
creates a WriteOnlyCell and returns it to the caller
@param value: value for cell
@param route_type: fills a color based on route_type [RTE, SM]
@param diff: fills a color based on diff type [ORANGE, BLUE]
'''
def create_cell(value, route_type, diff=None):
    cell = WriteOnlyCell(ws=output_worksheet, value=value)
    if route_type == 'RTE':
        if diff == ORANGE and has_value(cell):
            cell.fill = ORANGE_DIFF_FILL
        elif diff == BLUE and has_value(cell):
            cell.fill = BLUE_DIFF_FILL
        else:
            cell.fill = RTE_FILL
    elif route_type == 'SM':
        if diff == ORANGE and has_value(cell):
            cell.fill = ORANGE_DIFF_FILL
        elif diff == BLUE and has_value(cell):
            cell.fill = BLUE_DIFF_FILL
        else:
            cell.fill = SM_FILL
    return cell

# %%
def part_of_change(cell):
    try:
        if cell.fill.fgColor.rgb != '00000000':
            return True
    except AttributeError:
        return False
    return False

# %%
'''
given a route_type and operation, render the extra operation to the output_worksheet
@param route_type: responsible for determining type of output
@param operation: operation to output
'''
from openpyxl.writer.write_only import WriteOnlyCell
def render_extra_operation(route_type, operation):
    if type(operation) != Operation:
        print('[X] render_extra_operation recieved bad operation.')
        return False
    
    write_header()
    
    if route_type == 'RTE':
        for row in operation.get_operation_as_output('RTE', extra=True, difftype=ORANGE):
            output_worksheet.append(row)
        print('\t[+]Output extra RTE operation:', operation)
    elif route_type == 'SM':
        for row in operation.get_operation_as_output('SM', extra=True, difftype=BLUE):
            output_worksheet.append(row)
        print('\t[+]Output extra SM operation', operation)
    else:
        print('[X]render_extra_operation recieved bad route_type')

# %%
'''
compares the given routes. RTE and SM routes must be present at a minimum
    if MM route is present, logic will account for the sheet automatically
@return: openpyxl WriteOnlyWorksheet to be saved output containing the route differences  
'''

def compare_routes(rte_route, sm_route, mm_route=None):
    
    #Operation numbers stored as list
    rte_operation_nums = rte_route.get_operation_nums()
    sm_operation_nums = sm_route.get_operation_nums()
    
    
    
    #Parallel cursors to account for each route potentially having extra (unique) operations
    rte_cursor = 0
    sm_cursor = 0
    
    
    
    #Loop will run until the cursor for each route is at the route's last operation
    comparing = True
    
    while comparing:
        #print('RTE cursor:', rte_cursor, 'SM cursor:', sm_cursor)
        '''
        Handling extra operations in either the RTE or SM sheet
        If an SM sheet is present, check against sheet to see if can be neutralized
        '''
        
        rte_op_num_str = rte_operation_nums[rte_cursor]
        sm_op_num_str = sm_operation_nums[sm_cursor]
        
        
        #If the current operation numbers do not equal each other, either the RTE or SM has an extra operation
        if rte_operation_nums[rte_cursor] != sm_operation_nums[sm_cursor]:
            print('[X]Operation misalign. RTE: ', rte_operation_nums[rte_cursor], 'SM:', sm_operation_nums[sm_cursor])
            
            #Store our operation numbers as floats for number comparisons
            
            
            rte_op_num = float(rte_operation_nums[rte_cursor])
            sm_op_num = float(sm_operation_nums[sm_cursor])
            
            #If the RTE contains an operation that is not in the SM 
            #AND the SM contains and operation that is not in the RTE
            #Consider a complete mismatch senario where both operations are considered extra
            #Ignore cursors
            if rte_route.has_operation(sm_op_num_str) == False and sm_route.has_operation(rte_op_num_str) == False:
                #print('Complete mismatch!')
                print('\t[X]Extra RTE operation', rte_op_num_str)
                render_difference(rte_route.operations[rte_op_num_str], None)
                print('\t[X]Extra SM operation', sm_op_num_str)
                render_difference(None, sm_route.operations[sm_op_num_str])
            
            
            
            #If the SM operation number is ahead of the RTE, the RTE has an extra operation
            elif rte_op_num < sm_op_num:
                #Increment the RTE cursor until the operation numbers are realigned
                while rte_op_num < sm_op_num:
                    print('\t[X]Extra RTE operation', rte_op_num_str)
                    render_difference(rte_route.operations[rte_op_num_str], None)
                    #render_difference(rte_route.operations[rte_op_num_str], None)
                    rte_cursor += 1                    
                    rte_op_num = float(rte_operation_nums[rte_cursor])
                    
                print('[+]Operations realigned. RTE: ', rte_operation_nums[rte_cursor], 'SM:', sm_operation_nums[sm_cursor])
                #Now need to compare realigned operaions
                
                rte_op_num_str = rte_operation_nums[rte_cursor]
                sm_op_num_str = sm_operation_nums[sm_cursor]
                print('[+]Comparing RTE:', rte_route.operations[rte_op_num_str], 'SM:', sm_route.operations[sm_op_num_str])
                if rte_route.operations[rte_op_num_str] != sm_route.operations[sm_op_num_str]:
                #Operation diff
                    if (rte_route.operations[rte_op_num_str].part_of_change == False and 
                        mm_route.has_operation(rte_op_num_str) and 
                        sm_route.operations[rte_op_num_str] == mm_route.operations[rte_op_num_str]):
                        print('\t[+]Operation difference neutralized by MM sheet.:')
                    else:
                        render_difference(rte_route.operations[rte_op_num_str], sm_route.operations[sm_op_num_str])
                else:
                    print('\t[+]Operations equal.:', rte_route.operations[rte_op_num_str], 'SM:', sm_route.operations[sm_op_num_str])
                
                
            #If the RTE operation number is ahead of the SM spreadsheet, the SM sheet has an extra operation
            elif rte_op_num > sm_op_num:
                #Increment the SM cursor until the operation numbers are realigned
                while rte_op_num > sm_op_num:
                    print('\tExtra SM operation', sm_op_num_str)
                    render_difference(None, sm_route.operations[sm_op_num_str])
                    #render_difference(None, sm_route.operations[sm_op_num_str])
                    sm_cursor += 1
                    sm_op_num = float(sm_operation_nums[sm_cursor])
                    
                print('[+]Operations realigned. RTE: ', rte_operation_nums[rte_cursor], 'SM:', sm_operation_nums[sm_cursor])
                #Now need to compare realigned operaions
                
                rte_op_num_str = rte_operation_nums[rte_cursor]
                sm_op_num_str = sm_operation_nums[sm_cursor]
                if rte_route.operations[rte_op_num_str] != sm_route.operations[sm_op_num_str]:
                #Operation diff
                    if (rte_route.operations[rte_op_num_str].part_of_change == False and 
                        mm_route.has_operation(rte_op_num_str) and 
                        sm_route.operations[rte_op_num_str] == mm_route.operations[rte_op_num_str]):
                        print('\t[+]Operation difference neutralized by MM sheet.:')
                    else:
                        render_difference(rte_route.operations[rte_op_num_str], sm_route.operations[sm_op_num_str])
                else:
                    print('\t[+]Operations equal.:', rte_route.operations[rte_op_num_str], 'SM:', sm_route.operations[sm_op_num_str])
    
            #Safe check - if control falls here means that somehow the operation numbers are not less than/ greater than eachother AND not equal to eachother...
            else:
                print('[X]You should not be here, check operation alignment loop.')
        #Operation numbers are equal, proceed to normal operation comparison
        else:
            print('[+]Comparing RTE:', rte_route.operations[rte_op_num_str], 'SM:', sm_route.operations[sm_op_num_str])
            #print('[+]Operation numbers equal. RTE:', rte_operation_nums[rte_cursor], 'SM:', sm_operation_nums[sm_cursor])
            if rte_route.operations[rte_op_num_str] != sm_route.operations[sm_op_num_str]:
                #Operation diff
                if (rte_route.operations[rte_op_num_str].part_of_change == False and 
                        mm_route.has_operation(rte_op_num_str) and 
                        sm_route.operations[rte_op_num_str] == mm_route.operations[rte_op_num_str]):
                        print('\t[+]Operation difference neutralized by MM sheet.:')
                else:
                    render_difference(rte_route.operations[rte_op_num_str], sm_route.operations[sm_op_num_str])
            else:
                print('\t[+]Operations equal.:', rte_route.operations[rte_op_num_str], 'SM:', sm_route.operations[sm_op_num_str])
        #Increment our loop control variables
        rte_cursor += 1
        sm_cursor += 1
        
        
        #If the RTE or SM cursors are at the end of the routes, we are done comparing
        if rte_cursor == rte_route.get_num_operations() or sm_cursor == sm_route.get_num_operations():
            comparing = False
    
    #If either route is not equal to its cursor, it has extra trailing operations. 
    #For example, RTE-SM match for operations 1-10, but SM has operations 11-15, where RTE only has 1-10
    #Can assume these operations are equal
    while rte_cursor != rte_route.get_num_operations():
        rte_op_num_str = rte_operation_nums[rte_cursor]
        print('[X]Extra RTE operation', rte_op_num_str)
        render_difference(rte_route.operations[rte_op_num_str], None)
        rte_cursor += 1   
    while sm_cursor != sm_route.get_num_operations():
        sm_op_num_str = sm_operation_nums[sm_cursor]
        print('[X]Extra SM operation', sm_op_num_str)
        render_difference(None, sm_route.operations[sm_op_num_str])
        sm_cursor += 1

# %%
def render_difference(rte_operation, sm_operation):
    print('\t[+]Writing operation difference.')
    
    write_header()
    row_counter = 0
    if type(rte_operation) == Operation and type(sm_operation) == Operation:
        for rte_row, sm_row in zip(rte_operation.rows, sm_operation.rows):
            temp_row = []
            for rte_cell, sm_cell in zip(rte_row, sm_row):
                if rte_cell.value != sm_cell.value and part_of_change(rte_cell):
                    temp_row.append(create_cell(rte_cell.value, 'RTE', ORANGE))
                    temp_row.append(create_cell(sm_cell.value, 'SM', ORANGE))
                elif rte_cell.value != sm_cell.value and not part_of_change(rte_cell):
                    temp_row.append(create_cell(rte_cell.value, 'RTE', BLUE))
                    temp_row.append(create_cell(sm_cell.value, 'SM', BLUE))
                else:
                    temp_row.append(create_cell(rte_cell.value, 'RTE'))
                    temp_row.append(create_cell(sm_cell.value, 'SM'))
            row_counter += 1
            output_worksheet.append(temp_row)
    
    #print('Row Counter:', row_counter, 'RTE Rows', len(rte_operation.rows), 'SM Rows', len(sm_operation.rows))
    #Extra RTE line
    while rte_operation != None and len(rte_operation.rows) > row_counter:
        temp_row = []
        row = [cell for cell in rte_operation.rows[row_counter]]
        for cell in row:
            if part_of_change(cell):
                temp_row.append(create_cell(cell.value, 'RTE', ORANGE))
                temp_row.append(create_cell('', 'SM'))
            else:
                temp_row.append(create_cell(cell.value, 'RTE', BLUE))
                temp_row.append(create_cell('', 'SM'))
        output_worksheet.append(temp_row)
        row_counter += 1
                
    while sm_operation != None and len(sm_operation.rows) > row_counter:
        temp_row = []
        row = [cell for cell in sm_operation.rows[row_counter]]
        for cell in row:
            if part_of_change(cell):
                temp_row.append(create_cell(cell.value, 'RTE', ORANGE))
                temp_row.append(create_cell('', 'SM'))
            else:
                temp_row.append(create_cell(cell.value, 'RTE', BLUE))
                temp_row.append(create_cell('', 'SM'))
        output_worksheet.append(temp_row)        
        row_counter += 1

# %%
'''
@OrderedDict: Used as main data structure to store operations in the form
    (Key, Value)    ->    (Operation Number, Operation Class) 
'''

from collections import OrderedDict

'''
@Route: Stores all operations for a given route.
'''
class Route():
    
    '''
    @operations: Stores all operations for given route. Incoming values will be Operation type.
    @route_id: ID of the route pulled from the report_id
    @route_type: Will be either RTE (submitted), SM (staged chages), MM (production values)
    '''
    def __init__(self):
        self.operations = OrderedDict()
        self.route_id = None
        self.product_id = None
        self.route_type = None
        
    '''
    @return: returns the route id if not None, else 'NoSetRouteID' as error message
    '''
    def __str__(self):
        if self.route_id != None and self.route_type != None:
            return 'Route ID: ' + self.route_id + ', ' + self.product_id + ' | '  + self.route_type + ' | No. of Operations: ' + str(self.get_num_operations())  
        else:
            return 'NoSetRouteID'
    
    '''
    adds an operation to the route
    @param operation: will be of Operation type; operation to be added to route
        assuming operations are in sequential order
    '''
    def add_operation(self, operation):
        self.operations[str(operation)] = operation
        
    '''
    returns the route's operations to the caller
    @return: returns the operations of the route
    '''
    def get_operations(self):
        return self.operations
    
    '''
    sets the route's route ID
    @param route_id: ID of the current route
    '''
    def set_route_id(self, route_id):
        self.route_id = route_id
    
    '''
    sets the route's product ID
    @param product_id: product ID of the route
    '''
    def set_product_id(self, product_id):
        self.product_id = product_id
        
    '''
    sets the route's route type
    @param route_type: type of the current route
    '''
    def set_route_type(self, route_type):
        self.route_type = route_type
    
    '''
    returns total number of operations to the caller
    @return: int of total number of operations
    '''
    def get_num_operations(self):
        return len(self.operations)
    
    '''
    returns a list of the route's operation numbers (OrderedDict's keys)
    @return: returns a full list of operation numbers
    '''
    def get_operation_nums(self):
        return list(self.operations.keys())
    
    '''
    returns the last operation of the route to the caller
    @return: returns the last operation to the caller
    '''
    def get_last_operation(self):
        return self.operations[self.get_operation_nums()[self.get_num_operations()-1]]
    
    '''
    returns true if the route has the given operation, false otherwise
    @param operation: operation to look for
    '''
    def has_operation(self, operation):
        try:
            self.operations[operation]
            return True
        except KeyError:
            return False
        
    '''
    returns the route's route ID to the caller
    '''
    def get_route_id(self):
        return self.route_id
    
    '''
    returns the route's product ID to the caller
    '''
    def get_product_id(self):
        return self.product_id

# %%
class Operation():
    
    '''
    constructor
    '''
    def __init__(self):
        self.rows = []
        self.flagged_for_removal = False
        self.part_of_change = False
        
    '''
    returns the current operation's full operation number 
        'XXXX.XXXX'
    @return: operation's operation number
    '''
    def __str__(self):
        return self.fix_operation_no(self.rows[0][1].value)
    
    def __eq__(self, other_op):
        
        if type(other_op) != Operation:
            return False
        
        #Get operation as 2D array
        operation_as_list = self.get_operation_as_list()
        other_operation_as_list = other_op.get_operation_as_list()
        
        #Assume not the same if lengths are different 
        if len(operation_as_list) != len(other_operation_as_list):
            print('\t[X]Operation difference due to length.')
            return False
        
        #Operations are same length, zip is basically parallel comparison
        for row, other_row in zip(operation_as_list, other_operation_as_list):
            if row != other_row:
                print('\t[X]Operation difference due to value.')
                return False
            
        return True
    
    '''
    returns true if the current operation has no rows
    @return: True if the operation is empty; False otherwise
    '''
    def is_empty(self):
        return len(self.rows) == 0
    
    '''
    adds a row to the operation,
        detects for None value types (rather than ''),
        ensures the row is now all empty cells
    @param row: row from openpyxl ReadOnlyWorksheet
    '''
    def add_row(self, row):
        if not all(cell.value == None or cell.value == '' for cell in row):
            if any(cell.value == None for cell in row):
                pass
                #print('Detected None cell value.')
            try:
                if any(cell.fill.fgColor.rgb == RED for cell in row):
                    self.flagged_for_removal = True
                elif any(part_of_change(cell) == True for cell in row):
                    self.part_of_change = True
            except AttributeError:
                #When cells have fill type 'None' program crashes due to 'None' not having a value 'RGB'
                pass
            self.rows.append([cell for cell in row])
            
    '''
    prints the operation to the console
    @param log: log shall be set to None unless called by log_operation
    '''
    def print_operation(self, log=None):
        for row in self.rows:
            print([cell.value for cell in row], file=log)
    
    '''
    logs the operation to the given file
        append mode - if file exists it will be appended to not overwritten
    @param file_name: file_name of the log file
    '''
    def log_operation(self, file_name):
        with open(file_name, 'a+') as log_file:
            self.print_operation(log=log_file)
        log_file.close()
    
    '''
    sets and cleans the operation number incoming from a openpyxl ReadOnlyCell
        needs to cast to string in case Excel converted operation number to float
        ensures the format XXXX.XXXX 
        note that 100.XXXX and 10.XXXX are legal operation numbers
    @param operation_no: incoming cell value from where the operation number was encountered
    '''
    def fix_operation_no(self, operation_no):
        operation_no = str(operation_no)
        
        if '.' not in operation_no:
            operation_no = operation_no + '.0000'
        else:
            while len(operation_no.split('.')[1]) < 4:
                operation_no  = operation_no + '0'
        return operation_no
    
    '''
    returns the operation number to the caller
    @return: returns the operation's operation number to caller as float
    '''
    def get_operation_no(self):
        return float(self.fix_operation_no(self.rows[0][1].value))
    
    '''
    returns the operation number to the caller as a string
    @return: returns a str representation of the operations operation number
    '''
    def get_operation_no_str(self):
        return self.fix_operation_no(self.rows[0][1].value)
    
    '''
    returns an array of openpyxl WriteOnlyCells that can than be outputted to the diff worksheet
        depending on parameters, the caller will recieve properly highlighted cells
    @param route_type: RTE and SM are valid types. Will append placeholder WriteOnlyCells appropriately
        RTE will append cells in the order (RTE value, blank)
        SM will append cells in the order (blank, SM value)
    @param extra: if operation is not in other route extra is True, false otherwise
    @param difftype: If difference is inside scope of change, difftpye will be orange,
        blue otherwise
    '''
    #Theres probably a really short way to do this with list comprehension...
    def get_operation_as_output(self, route_type, extra=False, difftype=None):
        #2D array to return
        returned = []
        
        
        for row in self.rows:
            #temp is a temporary list that will act as a spreadsheet 'row'
            temp = []
            for cell in row:
                
                if route_type == 'RTE':
                    #If the current RTE cell is an extra operation, highlight it as a difference
                    if(extra):
                        temp.append(create_cell(cell.value, 'RTE', diff=difftype))
                    #The current RTE cell does not need any highlighting
                    else:
                        temp.append(create_cell(cell.value, 'RTE'))
                        
                    #Add blank SM cell (placeholder)
                    temp.append(create_cell('', 'SM'))
                
                elif route_type == 'SM':
                    #Add blank RTE cell (placeholder)
                    temp.append(create_cell('', 'RTE'))
                    
                    #If the current SM cell is an extra operation, highlight it as a difference
                    if(extra):
                        temp.append(create_cell(cell.value, 'SM', diff=difftype))
                    #Current SM cell does not need any highlighting
                    else:
                        temp.append(create_cell(cell.value, 'SM'))
            #append the 'row'
            returned.append(temp)
        return returned
    
    '''
    returns the operation as a cleaned* 2D list to the caller of plain string type values
        *All none types will be convered into empty strings for ease of comparison
        *Comment column will be returned as ''
            this is done by enumerating the cell and row values which will act as a row,column counter
            if row_count and cell_count are 0, we know its the comment area
            [0,0] [0,1] [0,2]
            [1,0] [1,1] [1,2]
            [2,0] [2,1] [2,2]
    @return: returns the operation represented as a 2D list (think of slice of a spreadsheet)
    '''
    
    def get_operation_as_list(self):
        return [['' if cell_count == 0 and row_count == 0 else cell.value if cell.value != None else '' for cell_count, cell in enumerate(row)] for row_count, row in enumerate(self.rows)]
    '''
    list comprehension equivalent to:
    returned = []
    for row in self.rows:
        temp = []
        for cell in row:
            if cell.value != None:
                temp.append(cell.value)
            else:
                temp.append('')
    return returned
    <3 python
    '''

# %%
from openpyxl.styles.borders import Border, Side

def format_output(filepath):
    
    book = oxl.load_workbook(filepath)
    
    
    sheet = book['RTE-SM Compare'] 
    
    sheet.row_dimensions[1].height = 55
    
    
    header_list = [
        'Comments',
        'Full Oper Num',
        'Module',
        'Module Description',
        'Process Def',
        'Photo Layer',
        'PD Type',
        'PD Name',
        'PD Description',
        'Department',
        'PD User Data Sets - Name',
        'PD User Data Sets - Value',
        'Operation User Data Sets - Name',
        'Operation User Data Sets - Value',
        'Mondatory',
        "Carrier Category",
        "LR Context Type",
        "LR Context",
        "Logical Recipe",
        "LR Description",
        "Resolved Pre1 Script",
        "Resolved Pre2 Script",
        'Resolved Post Script',
        'Equipment',
        'Equipment Recipe',
        'Recipe Description',
        'Stage ID',
        'Proc (min)',
        'Wait (min)',
        'WPH'
    ]
    for col in range(1,61,2):
        #merge necessary cells
        sheet.merge_cells(start_row=1, end_row=1, start_column=col, end_column=col+1)
        sheet.merge_cells(start_row=2, end_row=2, start_column=col, end_column=col+1)
        sheet.merge_cells(start_row=3, end_row=3, start_column=col, end_column=col+1)
        
        #assign values, center align
        sheet.cell(row=1, column=col, value=header_list[int((col-1)/2)]).alignment = oxl.styles.alignment.Alignment(horizontal='center', wrap_text=True)
        sheet.cell(row=2, column=col, value="Orange: ##").alignment = oxl.styles.alignment.Alignment(horizontal='center', wrap_text=True)
        sheet.cell(row=3, column=col, value="Blue: ##").alignment = oxl.styles.alignment.Alignment(horizontal='center', wrap_text=True)
        
        #cell coloring
        sheet.cell(row=1, column=col).fill = oxl.styles.fills.PatternFill(patternType='solid', fgColor='FFC0C0C0')
        sheet.cell(row=2, column=col).fill = oxl.styles.fills.PatternFill(patternType='solid', fgColor='FFFABF8F')
        sheet.cell(row=3, column=col).fill = oxl.styles.fills.PatternFill(patternType='solid', fgColor='FF92CDDC')
        
        #column sizing
        sheet.column_dimensions[oxl.utils.get_column_letter(col)].width = 15
        sheet.column_dimensions[oxl.utils.get_column_letter(col+1)].width = 15
        
        #borders
        sheet.cell(row=1, column=col).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        sheet.cell(row=1, column=col+1).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        sheet.cell(row=2, column=col).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        sheet.cell(row=2, column=col+1).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        sheet.cell(row=3, column=col).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        sheet.cell(row=3, column=col+1).border = Border(left=Side(style='thin'),
                                                      right=Side(style='thin'),
                                                      top=Side(style='thin'),
                                                      bottom=Side(style='thin'))
        
        #font
        sheet.cell(row=1, column=col).font = oxl.styles.fonts.Font(name='Consolas',
                                                                  bold=True,
                                                                  size=14)
        sheet.cell(row=2, column=col).font = oxl.styles.fonts.Font(name='Consolas',
                                                                  bold=True,
                                                                  size=10)
        sheet.cell(row=3, column=col).font = oxl.styles.fonts.Font(name='Consolas',
                                                                  bold=True,
                                                                  size=10)
    blue = 0
    orange = 0
    #loop through each column in the sheet
    for index, col in enumerate(sheet.columns):
        
        #loop through each cell in each column
        for cell in col:
            #detecting and counting orange color
            #print(cell.fill.fgColor.rgb)
            if (cell.fill.fgColor.rgb == ORANGE_DIFF_HEX):
                orange += 1
            #detecting and counting blue color
            if(cell.fill.fgColor.rgb == BLUE_DIFF_HEX):
                blue += 1
            #orange counter located at row 2
            #blue counter located at row 3
        if index % 2 != 0:
            currcol = oxl.utils.coordinate_from_string(prev.coordinate)[0]
            orange_coord = currcol + '2'
            blue_coord = currcol + '3'
            sheet[orange_coord].value = "Orange: " + str(orange) 
            sheet[blue_coord].value = "Blue: " + str(blue)
            #print(orange_coord, blue_coord,sheet[orange_coord].value, sheet[blue_coord].value, sheet[blue_coord])
            #reset counters
            blue = 0
            orange = 0
        prev = cell
        #print(currcol)
    sheet.sheet_view.zoomScale = 70
    book.save(filepath)

# %%
'''
writes the header to the openpyxl WriteOnly spreadsheet output_worksheet
'''
def write_header():
    rte_header = WriteOnlyCell(ws=output_worksheet, value='RTE')
    sm_header = WriteOnlyCell(ws=output_worksheet, value='SM')
    
    rte_header.fill = RTE_FILL
    sm_header.fill = SM_FILL
    
    rte_header.border = ALL_BORDER
    sm_header.border = ALL_BORDER
    
    rte_header.font = HEADER_FONT
    sm_header.font = HEADER_FONT
    
    rte_header.alignment = CENTER_ALIGN
    sm_header.alignment = CENTER_ALIGN
    
    temp = []
    for header_cell in range(NUM_OUTPUT_COLS):
        temp.append(rte_header)
        temp.append(sm_header)
    output_worksheet.append(temp)
